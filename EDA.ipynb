# %%
import pandas as pd 
import numpy as np
import os
import seaborn as sns

# %%
#Use this file path for pc
filepath = r"D:\gradschool\Capstone"
#Use this file path for mac 
#filepath = r"/Users/jacksonjoyner/Desktop/MSBA/Capstone/UseThisData/"
os.chdir(filepath)

# %%
playerdf = pd.read_csv("ImpactScoreData.csv")
playerdf
# Out:
#        league  year   split             date  side  playername position  \
# 0      EU LCS  2014  Spring  3/28/2014 16:14  Blue    fredy122      top
# 1      EU LCS  2014  Spring  3/28/2014 16:14  Blue  Svenskeren      jng
# 2      EU LCS  2014  Spring  3/28/2014 16:14  Blue       Jesiz      mid
# 3      EU LCS  2014  Spring  3/28/2014 16:14  Blue  CandyPanda      bot
# 4      EU LCS  2014  Spring  3/28/2014 16:14  Blue      nRated      sup
# ...       ...   ...     ...              ...   ...         ...      ...
# 92595     LCS  2021  Spring   4/3/2021 21:32   Red     Alphari      top
# 92596     LCS  2021  Spring   4/3/2021 21:32   Red    Santorin      jng
# 92597     LCS  2021  Spring   4/3/2021 21:32   Red      Jensen      mid
# 92598     LCS  2021  Spring   4/3/2021 21:32   Red    Tactical      bot
# 92599     LCS  2021  Spring   4/3/2021 21:32   Red      CoreJJ      sup
#
#           teamname  kills  deaths  ...  impactscore       KDA        KP  \
# ...

# %%
playerdf.describe()
# Out:
#                year         kills        deaths       assists   doublekills  \
# count  92600.000000  92600.000000  92600.000000  92600.000000  92600.000000
# mean    2017.965767      2.408294      2.412343      5.745292      0.254590
# std        1.967087      2.399363      1.770729      4.050772      0.571132
# min     2014.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2017.000000      1.000000      1.000000      3.000000      0.000000
# 50%     2018.000000      2.000000      2.000000      5.000000      0.000000
# 75%     2020.000000      4.000000      4.000000      8.000000      0.000000
# max     2021.000000     20.000000     14.000000     45.000000      6.000000
#
#        firstbloodkill  firstbloodassist  firstbloodvictim           dpm  \
# count    92600.000000      92600.000000      92600.000000  92600.000000
# mean         0.100086          0.152354          0.100032    372.797962
# ...

# %%
sns.catplot(x="position",y='kills',kind = "box",data= playerdf)

# %%
sns.catplot(x="position",y='deaths',kind = "box",data= playerdf)

# %%
sns.catplot(x="position",y='assists',kind = "box",data= playerdf)

# %%
sns.catplot(x="position",y='goldat15', kind="box",data=playerdf)

# %%
sns.catplot(x="position",y='xpat15',kind="box", data=playerdf)

# %%
sns.catplot(x='position',y = 'earnedgoldshare',kind="box",data=playerdf)

# %%
sns.catplot(x='position',y = 'earned gpm',kind="box",data=playerdf)

# %%
sns.catplot(x='position',y = 'earned gpm',kind="box",data=playerdf)

# %%
vas = ['kills','deaths','assists','goldat15','xpat15',"earnedgoldshare",'earned gpm','position']
variables = playerdf[vas]
variables
sns.pairplot(variables,hue="position")
