# %%
import pandas as pd
import numpy as np
import os

# %%
filepath = "D:\gradschool\Capstone\CapstoneWorkSpace6\Split"
os.chdir(filepath)

# %%
df = pd.read_csv("2021_player_data.csv")
df
# Out:
#                        gameid datacompleteness  \
# 0       ESPORTSTMNT06_1880262              NaN
# 1       ESPORTSTMNT06_1880262              NaN
# 2       ESPORTSTMNT06_1880262              NaN
# 3       ESPORTSTMNT06_1880262              NaN
# 4       ESPORTSTMNT06_1880262              NaN
# ...                       ...              ...
# 122055  ESPORTSTMNT02_1929156              NaN
# 122056  ESPORTSTMNT02_1929156              NaN
# 122057  ESPORTSTMNT02_1929156              NaN
# 122058  ESPORTSTMNT02_1929156              NaN
# 122059  ESPORTSTMNT02_1929156              NaN
#
#                                                       url  league  year  \
# 0       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# 1       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# 2       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# 3       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# ...

# %% [markdown]
# There are a number of columns that contain little to no data, so we are just going to remove them from the df

# %%
df.drop(["firstdragon", 'dragons','opp_dragons','elementaldrakes','opp_elementaldrakes','infernals','mountains','clouds','oceans','dragons (type unknown)','elders','opp_elders','firstherald','heralds','opp_heralds','firstbaron','barons','opp_barons','firsttower','towers','opp_towers','firstmidtower','firsttothreetowers','turretplates','opp_turretplates','inhibitors','opp_inhibitors'], axis = 1)
# Out:
#                        gameid datacompleteness  \
# 0       ESPORTSTMNT06_1880262              NaN
# 1       ESPORTSTMNT06_1880262              NaN
# 2       ESPORTSTMNT06_1880262              NaN
# 3       ESPORTSTMNT06_1880262              NaN
# 4       ESPORTSTMNT06_1880262              NaN
# ...                       ...              ...
# 122055  ESPORTSTMNT02_1929156              NaN
# 122056  ESPORTSTMNT02_1929156              NaN
# 122057  ESPORTSTMNT02_1929156              NaN
# 122058  ESPORTSTMNT02_1929156              NaN
# 122059  ESPORTSTMNT02_1929156              NaN
#
#                                                       url  league  year  \
# 0       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# 1       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# 2       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# 3       http://matchhistory.na.leagueoflegends.com/en/...     LEC  2021
# ...

# %%
files = []
location = os.listdir(filepath)
for item in location:
    files.append(item)

# %%
for file in files:
    if "player" in file:
        df = pd.read_csv(file)
        df = df.drop(columns=["firstdragon", 'dragons','opp_dragons','elementaldrakes','opp_elementaldrakes','infernals','mountains','clouds','oceans','dragons (type unknown)','elders','opp_elders','firstherald','heralds','opp_heralds','firstbaron','barons','opp_barons','firsttower','towers','opp_towers','firstmidtower','firsttothreetowers','turretplates','opp_turretplates','inhibitors','opp_inhibitors'], axis = 1)        
        df.to_csv("updated_"+file, index = False)
    else:
        df = pd.read_csv(file)
        df = df.drop(columns=["playername",'playerid','firstbloodkill','firstbloodassist','firstbloodvictim'],axis = 1)
        df.to_csv("updated_"+file,index= False)
