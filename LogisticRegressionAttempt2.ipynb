# %%
import pandas as pd
import numpy as np
import os
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
#Use this file path for pc
#filepath = r"D:\gradschool\Capstone\CapstoneWorkSpace6\UseThisData"
#Use this file path for mac 
filepath = r"/Users/jacksonjoyner/Desktop/MSBA/Capstone/UseThisData/"
os.chdir(filepath)

# %%
allplayerdf = pd.read_csv("UseThisPlayerData.csv")
# Out:
# /Users/jacksonjoyner/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (21,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
leagueset = list(allplayerdf["league"])
leagueset = set(leagueset)
dfuse = pd.DataFrame()
league = ["EU LCS",'NA LCS','LCK','LPL','LEC','LCS']
for item in league:
    dfnew = allplayerdf[allplayerdf["league"] == item]
    dfuse = dfuse.append(dfnew)

dfuse
# Out:
#                        gameid datacompleteness  \
# 20           TRLH3/1002010064         complete
# 21           TRLH3/1002010064         complete
# 22           TRLH3/1002010064         complete
# 23           TRLH3/1002010064         complete
# 24           TRLH3/1002010064         complete
# ...                       ...              ...
# 497469  ESPORTSTMNT01/1424862         complete
# 497470  ESPORTSTMNT01/1424862         complete
# 497471  ESPORTSTMNT01/1424862         complete
# 497472  ESPORTSTMNT01/1424862         complete
# 497473  ESPORTSTMNT01/1424862         complete
#
#                                                       url  league  year  \
# 20      http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2017
# 21      http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2017
# 22      http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2017
# 23      http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2017
# 24      http://matchhistory.na.leagueoflegends.com/en/...  EU LCS  2017
# ...                                                   ...     ...   ...
# 497469  http://matchhistory.na.leagueoflegends.com/en/...     LCS  2020
# 497470  http://matchhistory.na.leagueoflegends.com/en/...     LCS  2020
# 497471  http://matchhistory.na.leagueoflegends.com/en/...     LCS  2020
# 497472  http://matchhistory.na.leagueoflegends.com/en/...     LCS  2020
# 497473  http://matchhistory.na.leagueoflegends.com/en/...     LCS  2020
#
#          split  playoffs                 date  game  patch  ...  opp_csat15  \
# 20      Spring         0  2017-03-17 19:05:05     2   7.05  ...       102.0
# 21      Spring         0  2017-03-17 19:05:05     2   7.05  ...        95.0
# 22      Spring         0  2017-03-17 19:05:05     2   7.05  ...       148.0
# 23      Spring         0  2017-03-17 19:05:05     2   7.05  ...       174.0
# 24      Spring         0  2017-03-17 19:05:05     2   7.05  ...         9.0
# ...        ...       ...                  ...   ...    ...  ...         ...
# 497469  Summer         0  2020-07-25 21:25:50     1  10.14  ...       106.0
# 497470  Summer         0  2020-07-25 21:25:50     1  10.14  ...        92.0
# 497471  Summer         0  2020-07-25 21:25:50     1  10.14  ...       154.0
# 497472  Summer         0  2020-07-25 21:25:50     1  10.14  ...       141.0
# 497473  Summer         0  2020-07-25 21:25:50     1  10.14  ...        21.0
#
#        golddiffat15 xpdiffat15 csdiffat15 killsat15 assistsat15 deathsat15  \
# 20            445.0       78.0        6.0       0.0         1.0        0.0
# 21             59.0     -836.0      -23.0       0.0         1.0        1.0
# 22          -1442.0    -1116.0      -42.0       0.0         0.0        1.0
# 23           -343.0     -392.0      -23.0       1.0         0.0        0.0
# 24            310.0       -6.0        2.0       0.0         1.0        1.0
# ...             ...        ...        ...       ...         ...        ...
# 497469       1774.0     1264.0       33.0       2.0         0.0        0.0
# 497470       -901.0      436.0       -1.0       0.0         2.0        1.0
# 497471       -619.0     -390.0      -15.0       0.0         0.0        1.0
# 497472       -770.0      494.0        2.0       0.0         0.0        0.0
# 497473       -765.0     -690.0        0.0       0.0         0.0        2.0
#
#        opp_killsat15 opp_assistsat15 opp_deathsat15
# 20               0.0             0.0            1.0
# 21               0.0             1.0            0.0
# 22               2.0             0.0            0.0
# 23               0.0             1.0            0.0
# 24               1.0             0.0            0.0
# ...              ...             ...            ...
# 497469           0.0             1.0            2.0
# 497470           2.0             2.0            0.0
# 497471           1.0             1.0            0.0
# 497472           1.0             1.0            0.0
# 497473           0.0             4.0            0.0
#
# [117584 rows x 94 columns]

# %%
gameids = list(dfuse["gameid"])
gameids = set(gameids)
nonulls = pd.DataFrame()
for ids in gameids:
    df = dfuse[dfuse["gameid"]== ids]
    if df.isnull().values.any() == True:
        #don't add to overall df
        print("There were nulls in "+ ids + " we are not using it for the model")
    else:
        nonulls = nonulls.append(df)
# Out:
# There were nulls in ESPORTSTMNT03_2005839 we are not using it for the model
# There were nulls in ESPORTSTMNT06/721794 we are not using it for the model
# There were nulls in 7385-10021 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2006174 we are not using it for the model
# There were nulls in TRLH1/1001770250 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1013631 we are not using it for the model
# There were nulls in 4906-6127 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1442192 we are not using it for the model
# There were nulls in TRLH3/10107 we are not using it for the model
# There were nulls in 4788-5837 we are not using it for the model
# There were nulls in TRLH3/1001930138 we are not using it for the model
# There were nulls in TRLH3/1002020098 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1830074 we are not using it for the model
# There were nulls in 3629-4578 we are not using it for the model
# There were nulls in 6629-8549 we are not using it for the model
# There were nulls in 5425-6870 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1031095 we are not using it for the model
# There were nulls in 7378-9993 we are not using it for the model
# There were nulls in TRKR1/1130310 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1684020 we are not using it for the model
# There were nulls in TRKR1/1050059 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1403220 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1415502 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1430955 we are not using it for the model
# There were nulls in 2145-2130 we are not using it for the model
# There were nulls in 2921-3249 we are not using it for the model
# There were nulls in 4362-5770 we are not using it for the model
# There were nulls in 4356-5749 we are not using it for the model
# There were nulls in 8001-11083 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1161934 we are not using it for the model
# There were nulls in TRLH1/1001800167 we are not using it for the model
# There were nulls in TRLH3/1001100108 we are not using it for the model
# There were nulls in TRLH3/1002580223 we are not using it for the model
# There were nulls in ESPORTSTMNT06/650517 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1443471 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1332603 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1093354 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1881437 we are not using it for the model
# There were nulls in 1560-1889 we are not using it for the model
# There were nulls in 2699-2706 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40068 we are not using it for the model
# There were nulls in TRLH3/1002110084 we are not using it for the model
# There were nulls in TRLH1/1002040245 we are not using it for the model
# There were nulls in 7646-10552 we are not using it for the model
# There were nulls in TRLH1/1002450088 we are not using it for the model
# There were nulls in 139-288 we are not using it for the model
# There were nulls in TRKR1/1040486 we are not using it for the model
# There were nulls in ESPORTSTMNT04/990770 we are not using it for the model
# There were nulls in TRLH3/20057 we are not using it for the model
# There were nulls in TRKR1/1090602 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1735182 we are not using it for the model
# There were nulls in 1099-1295 we are not using it for the model
# There were nulls in 6008-7439 we are not using it for the model
# There were nulls in TRLH3/1002000202 we are not using it for the model
# There were nulls in TRLH1/1000170158 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1133666 we are not using it for the model
# There were nulls in ESPORTSTMNT06/791000 we are not using it for the model
# There were nulls in 7620-10342 we are not using it for the model
# There were nulls in 5977-7364 we are not using it for the model
# There were nulls in 163-417 we are not using it for the model
# There were nulls in TRLH1/1001790082 we are not using it for the model
# There were nulls in TRLH1/1000110021 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1013217 we are not using it for the model
# There were nulls in TRLH3/1001990157 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1390170 we are not using it for the model
# There were nulls in TRLH1/1002690050 we are not using it for the model
# There were nulls in TRLH3/1001690064 we are not using it for the model
# There were nulls in TRLH1/1002290216 we are not using it for the model
# There were nulls in TRLH3/1002190117 we are not using it for the model
# There were nulls in 754-802 we are not using it for the model
# There were nulls in 4301-5423 we are not using it for the model
# There were nulls in ESPORTSTMNT06/280436 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1170219 we are not using it for the model
# There were nulls in 5423-6861 we are not using it for the model
# There were nulls in 7615-10331 we are not using it for the model
# There were nulls in TRLH3/1000380083 we are not using it for the model
# There were nulls in 7620-10343 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1886731 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1053197 we are not using it for the model
# There were nulls in 4915-6192 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1304391 we are not using it for the model
# There were nulls in 3561-4386 we are not using it for the model
# There were nulls in 6932-9323 we are not using it for the model
# There were nulls in 7367-9970 we are not using it for the model
# There were nulls in ESPORTSTMNT06/140928 we are not using it for the model
# There were nulls in ESPORTSTMNT06/771712 we are not using it for the model
# There were nulls in TRKR1/900224 we are not using it for the model
# There were nulls in TRLH3/1000300088 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1997525 we are not using it for the model
# There were nulls in 7969-10827 we are not using it for the model
# There were nulls in ESPORTSTMNT02/992625 we are not using it for the model
# There were nulls in TRLH1/1002650060 we are not using it for the model
# There were nulls in TRLH1/1002300083 we are not using it for the model
# There were nulls in ESPORTSTMNT04/970306 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1414311 we are not using it for the model
# There were nulls in TRLH3/1000370104 we are not using it for the model
# There were nulls in TRKR1/960069 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1830216 we are not using it for the model
# There were nulls in TRKR1/1170499 we are not using it for the model
# There were nulls in 5390-6585 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1287048 we are not using it for the model
# There were nulls in 4342-5660 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1510206 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1433759 we are not using it for the model
# There were nulls in 2685-2761 we are not using it for the model
# There were nulls in 2593-2341 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1143971 we are not using it for the model
# There were nulls in TRLH1/1000050099 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610224 we are not using it for the model
# There were nulls in 3614-4546 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1997159 we are not using it for the model
# There were nulls in 172-465 we are not using it for the model
# There were nulls in 6660-8770 we are not using it for the model
# There were nulls in 2585-2311 we are not using it for the model
# There were nulls in TRLH1/1002110295 we are not using it for the model
# There were nulls in 3573-4419 we are not using it for the model
# There were nulls in TRLH3/1001700033 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1693567 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1351837 we are not using it for the model
# There were nulls in TRLH1/1002060126 we are not using it for the model
# There were nulls in TRLH3/1001310029 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1031204 we are not using it for the model
# There were nulls in 1568-1942 we are not using it for the model
# There were nulls in ESPORTSTMNT06/250523 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1143404 we are not using it for the model
# There were nulls in 1516-1594 we are not using it for the model
# There were nulls in TRKR1/980066 we are not using it for the model
# There were nulls in 5430-6912 we are not using it for the model
# There were nulls in 4883-6071 we are not using it for the model
# There were nulls in TRLH2/2002300068 we are not using it for the model
# There were nulls in TRLH1/1002120133 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1441795 we are not using it for the model
# There were nulls in TRLH3/1000290172 we are not using it for the model
# There were nulls in 2968-3499 we are not using it for the model
# There were nulls in 2928-3275 we are not using it for the model
# There were nulls in 2617-2553 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1283154 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1724893 we are not using it for the model
# There were nulls in 6077-7574 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1091316 we are not using it for the model
# There were nulls in 3648-4629 we are not using it for the model
# There were nulls in 6598-8313 we are not using it for the model
# There were nulls in 1530-1669 we are not using it for the model
# There were nulls in TRLH3/1002210093 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1410145 we are not using it for the model
# There were nulls in 8093-11147 we are not using it for the model
# There were nulls in 1580-2002 we are not using it for the model
# There were nulls in 8109-11287 we are not using it for the model
# There were nulls in ESPORTSTMNT02/801119 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1294784 we are not using it for the model
# There were nulls in TRKR1/1040527 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1220728 we are not using it for the model
# There were nulls in TRLH1/1000120065 we are not using it for the model
# There were nulls in 7346-9925 we are not using it for the model
# There were nulls in TRLH3/1000210110 we are not using it for the model
# There were nulls in TRLH1/1001730132 we are not using it for the model
# There were nulls in TRLH1/1002270064 we are not using it for the model
# There were nulls in ESPORTSTMNT04/890254 we are not using it for the model
# There were nulls in 6955-9504 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1120173 we are not using it for the model
# There were nulls in TRLH1/1001560015 we are not using it for the model
# There were nulls in 5406-6701 we are not using it for the model
# There were nulls in TRLH1/1002330110 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40515 we are not using it for the model
# There were nulls in TRLH1/1002120319 we are not using it for the model
# There were nulls in ESPORTSTMNT06/730277 we are not using it for the model
# There were nulls in 6934-9344 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1060844 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1022932 we are not using it for the model
# There were nulls in TRLH1/1002270122 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1693626 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1996296 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1433058 we are not using it for the model
# There were nulls in 6658-8749 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1271091 we are not using it for the model
# There were nulls in TRLH1/1001030110 we are not using it for the model
# There were nulls in 6004-7428 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1831534 we are not using it for the model
# There were nulls in ESPORTSTMNT06/761971 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1000799 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1150490 we are not using it for the model
# There were nulls in TRLH1/1001790086 we are not using it for the model
# There were nulls in 3547-4357 we are not using it for the model
# There were nulls in 777-902 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1880170 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1816080 we are not using it for the model
# There were nulls in 3019-3949 we are not using it for the model
# There were nulls in 1591-2054 we are not using it for the model
# There were nulls in TRLH3/1000210052 we are not using it for the model
# There were nulls in 7315-9720 we are not using it for the model
# There were nulls in TRLH1/1001260045 we are not using it for the model
# There were nulls in ESPORTSTMNT06/620580 we are not using it for the model
# There were nulls in 2902-3164 we are not using it for the model
# There were nulls in TRLH1/1002670235 we are not using it for the model
# There were nulls in TRLH3/1002710036 we are not using it for the model
# There were nulls in 6660-8769 we are not using it for the model
# There were nulls in 3640-4611 we are not using it for the model
# There were nulls in 7358-9953 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1400896 we are not using it for the model
# There were nulls in 2917-3225 we are not using it for the model
# There were nulls in TRLH1/1001110098 we are not using it for the model
# There were nulls in TRLH1/1001740214 we are not using it for the model
# There were nulls in 1580-2003 we are not using it for the model
# There were nulls in TRLH1/1002470068 we are not using it for the model
# There were nulls in 2972-3545 we are not using it for the model
# There were nulls in TRKR1/1110331 we are not using it for the model
# There were nulls in 6252-8158 we are not using it for the model
# There were nulls in TRLH3/1001290055 we are not using it for the model
# There were nulls in 4081-5266 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1824054 we are not using it for the model
# There were nulls in TRLH1/1002490013 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1683767 we are not using it for the model
# There were nulls in 6241-8068 we are not using it for the model
# There were nulls in 3000-3805 we are not using it for the model
# There were nulls in TRLH3/1001020233 we are not using it for the model
# There were nulls in TRKR1/750688 we are not using it for the model
# There were nulls in TRLH3/1001180186 we are not using it for the model
# There were nulls in TRLH1/1001370028 we are not using it for the model
# There were nulls in 5370-6422 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1041084 we are not using it for the model
# There were nulls in 7982-10908 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1140505 we are not using it for the model
# There were nulls in 6258-8210 we are not using it for the model
# There were nulls in 5422-6850 we are not using it for the model
# There were nulls in TRLH3/1000300120 we are not using it for the model
# There were nulls in 6127-7752 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1144927 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1894761 we are not using it for the model
# There were nulls in TRLH3/1001900079 we are not using it for the model
# There were nulls in TRLH1/1001770141 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1250170 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1840955 we are not using it for the model
# There were nulls in TRLH3/1002020028 we are not using it for the model
# There were nulls in 4281-5377 we are not using it for the model
# There were nulls in 3631-4586 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1043122 we are not using it for the model
# There were nulls in TRLH3/1001580074 we are not using it for the model
# There were nulls in 6009-7441 we are not using it for the model
# There were nulls in WMC2TMNT1/290059 we are not using it for the model
# There were nulls in TRLH1/1002050161 we are not using it for the model
# There were nulls in 1536-1758 we are not using it for the model
# There were nulls in 8099-11205 we are not using it for the model
# There were nulls in TRKR1/1150702 we are not using it for the model
# There were nulls in TRLH1/1001400027 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2055160 we are not using it for the model
# There were nulls in 6683-8852 we are not using it for the model
# There were nulls in ESPORTSTMNT06/581069 we are not using it for the model
# There were nulls in 2951-3396 we are not using it for the model
# There were nulls in TRLH3/1001940150 we are not using it for the model
# There were nulls in TRLH3/1001700214 we are not using it for the model
# There were nulls in ESPORTSTMNT06/240148 we are not using it for the model
# There were nulls in ESPORTSTMNT06/750636 we are not using it for the model
# There were nulls in 8099-11206 we are not using it for the model
# There were nulls in 4931-6337 we are not using it for the model
# There were nulls in TRLH1/1001830086 we are not using it for the model
# There were nulls in 2694-2684 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1113147 we are not using it for the model
# There were nulls in 2988-3710 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440690 we are not using it for the model
# There were nulls in TRLH1/1002670210 we are not using it for the model
# There were nulls in TRLH1/1001730209 we are not using it for the model
# There were nulls in 7990-10941 we are not using it for the model
# There were nulls in 5376-6496 we are not using it for the model
# There were nulls in 760-851 we are not using it for the model
# There were nulls in 7664-10700 we are not using it for the model
# There were nulls in TRLH1/1002100142 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1691645 we are not using it for the model
# There were nulls in TRKR1/1140712 we are not using it for the model
# There were nulls in 4790-5845 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1170778 we are not using it for the model
# There were nulls in TRKR1/920063 we are not using it for the model
# There were nulls in 3009-3867 we are not using it for the model
# There were nulls in 2726-2834 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1673719 we are not using it for the model
# There were nulls in ESPORTSTMNT06/70439 we are not using it for the model
# There were nulls in 4790-5844 we are not using it for the model
# There were nulls in 6923-9255 we are not using it for the model
# There were nulls in TRLH3/1001590043 we are not using it for the model
# There were nulls in TRKR1/1100490 we are not using it for the model
# There were nulls in TRLH3/1001690079 we are not using it for the model
# There were nulls in 3641-4613 we are not using it for the model
# There were nulls in TRKR1/1080796 we are not using it for the model
# There were nulls in 4921-6241 we are not using it for the model
# There were nulls in 4889-6087 we are not using it for the model
# There were nulls in ESPORTSTMNT06/970740 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1820496 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1405442 we are not using it for the model
# There were nulls in TRLH1/1001330012 we are not using it for the model
# There were nulls in TRKR1/1150638 we are not using it for the model
# There were nulls in 1518-1605 we are not using it for the model
# There were nulls in TRLH3/1002040107 we are not using it for the model
# There were nulls in TRLH1/1002250185 we are not using it for the model
# There were nulls in ESPORTSTMNT06/811856 we are not using it for the model
# There were nulls in TRLH3/1001020112 we are not using it for the model
# There were nulls in TRLH1/30030 we are not using it for the model
# There were nulls in 182-486 we are not using it for the model
# There were nulls in 7351-9938 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1128226 we are not using it for the model
# There were nulls in TRLH1/1001690098 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1414788 we are not using it for the model
# There were nulls in TRLH1/1001670110 we are not using it for the model
# There were nulls in TRLH3/1001930127 we are not using it for the model
# There were nulls in ESPORTSTMNT06/551568 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1286938 we are not using it for the model
# There were nulls in 4331-5580 we are not using it for the model
# There were nulls in 3017-3925 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1032986 we are not using it for the model
# There were nulls in 130-270 we are not using it for the model
# There were nulls in 4340-5647 we are not using it for the model
# There were nulls in 138-287 we are not using it for the model
# There were nulls in 8016-11056 we are not using it for the model
# There were nulls in 6595-8287 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1411500 we are not using it for the model
# There were nulls in TRLH1/1000170101 we are not using it for the model
# There were nulls in 6700-8960 we are not using it for the model
# There were nulls in TRLH3/1002150241 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1694012 we are not using it for the model
# There were nulls in 2949-3387 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1160590 we are not using it for the model
# There were nulls in 7375-9979 we are not using it for the model
# There were nulls in TRLH3/1002620188 we are not using it for the model
# There were nulls in TRLH1/1001070013 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2147528 we are not using it for the model
# There were nulls in 2577-2266 we are not using it for the model
# There were nulls in TRKR1/1000116 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1441108 we are not using it for the model
# There were nulls in 2713-2783 we are not using it for the model
# There were nulls in TRLH1/1002710235 we are not using it for the model
# There were nulls in TRKR1/910486 we are not using it for the model
# There were nulls in TRLH1/1001090051 we are not using it for the model
# There were nulls in 6650-8690 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1691701 we are not using it for the model
# There were nulls in TRKR1/950363 we are not using it for the model
# There were nulls in 1589-2050 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1170233 we are not using it for the model
# There were nulls in TRLH3/1001540010 we are not using it for the model
# There were nulls in 2720-2810 we are not using it for the model
# There were nulls in TRLH1/1001250106 we are not using it for the model
# There were nulls in 4331-5576 we are not using it for the model
# There were nulls in 5985-7382 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1292006 we are not using it for the model
# There were nulls in 6261-8232 we are not using it for the model
# There were nulls in ESPORTSTMNT06/641682 we are not using it for the model
# There were nulls in ESPORTSTMNT06/300758 we are not using it for the model
# There were nulls in 1511-1563 we are not using it for the model
# There were nulls in ESPORTSTMNT06/550432 we are not using it for the model
# There were nulls in TRLH3/1001570094 we are not using it for the model
# There were nulls in TRLH3/1002620168 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1132087 we are not using it for the model
# There were nulls in 3597-4501 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1764144 we are not using it for the model
# There were nulls in TRLH3/1001530089 we are not using it for the model
# There were nulls in TRLH3/1002360057 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1560343 we are not using it for the model
# There were nulls in TRLH3/1002410035 we are not using it for the model
# There were nulls in 6606-8373 we are not using it for the model
# There were nulls in TRLH3/1001220050 we are not using it for the model
# There were nulls in 5401-6683 we are not using it for the model
# There were nulls in TRLH3/1001240051 we are not using it for the model
# There were nulls in TRLH3/1000110046 we are not using it for the model
# There were nulls in ESPORTSTMNT06/130222 we are not using it for the model
# There were nulls in 784-936 we are not using it for the model
# There were nulls in TRLH1/1001810068 we are not using it for the model
# There were nulls in TRLH1/1000070277 we are not using it for the model
# There were nulls in 3000-3807 we are not using it for the model
# There were nulls in TRLH1/1000220134 we are not using it for the model
# There were nulls in TRLH1/1002040392 we are not using it for the model
# There were nulls in ESPORTSTMNT06/341202 we are not using it for the model
# There were nulls in 6254-8181 we are not using it for the model
# There were nulls in 1507-1544 we are not using it for the model
# There were nulls in TRLH1/1002650062 we are not using it for the model
# There were nulls in 4350-5713 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1240457 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1011098 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1810385 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1415705 we are not using it for the model
# There were nulls in 4361-5768 we are not using it for the model
# There were nulls in 6045-7470 we are not using it for the model
# There were nulls in TRLH1/1002290272 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1033795 we are not using it for the model
# There were nulls in TRLH3/1001320023 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1436582 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1293319 we are not using it for the model
# There were nulls in 7677-10803 we are not using it for the model
# There were nulls in 6044-7469 we are not using it for the model
# There were nulls in TRLH1/1001560025 we are not using it for the model
# There were nulls in 6911-9186 we are not using it for the model
# There were nulls in 6128-7760 we are not using it for the model
# There were nulls in ESPORTSTMNT05_2060409 we are not using it for the model
# There were nulls in TRKR1/1040460 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1293964 we are not using it for the model
# There were nulls in 5986-7384 we are not using it for the model
# There were nulls in TRLH3/1001090135 we are not using it for the model
# There were nulls in TRLH1/1001770122 we are not using it for the model
# There were nulls in ESPORTSTMNT06/360276 we are not using it for the model
# There were nulls in TRLH3/1000040088 we are not using it for the model
# There were nulls in ESPORTSTMNT06/761293 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1412111 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1302635 we are not using it for the model
# There were nulls in TRLH3/1002220154 we are not using it for the model
# There were nulls in TRLH4/1002060073 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1306406 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2067212 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1332241 we are not using it for the model
# There were nulls in 2696-2697 we are not using it for the model
# There were nulls in TRLH1/1002310068 we are not using it for the model
# There were nulls in 2703-2715 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1141004 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1334858 we are not using it for the model
# There were nulls in 2708-2757 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1831202 we are not using it for the model
# There were nulls in 4380-5818 we are not using it for the model
# There were nulls in TRKR1/1130229 we are not using it for the model
# There were nulls in TRKR1/1130274 we are not using it for the model
# There were nulls in 6963-9562 we are not using it for the model
# There were nulls in TRLH1/1002310217 we are not using it for the model
# There were nulls in 4373-5800 we are not using it for the model
# There were nulls in TRLH1/1001040154 we are not using it for the model
# There were nulls in 4283-5383 we are not using it for the model
# There were nulls in 2960-3436 we are not using it for the model
# There were nulls in FRA1TMNT1/410318 we are not using it for the model
# There were nulls in ESPORTSTMNT06/551204 we are not using it for the model
# There were nulls in TRLH1/1000270128 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1414874 we are not using it for the model
# There were nulls in 4274-5361 we are not using it for the model
# There were nulls in 4289-5396 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40205 we are not using it for the model
# There were nulls in TRKR1/1000316 we are not using it for the model
# There were nulls in WMC2TMNT1/290073 we are not using it for the model
# There were nulls in 2926-3265 we are not using it for the model
# There were nulls in TRLH1/1001090100 we are not using it for the model
# There were nulls in TRLH3/1001530171 we are not using it for the model
# There were nulls in TRLH3/1001160051 we are not using it for the model
# There were nulls in 7358-9951 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1430676 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1023006 we are not using it for the model
# There were nulls in ESPORTSTMNT05_2070823 we are not using it for the model
# There were nulls in TRLH1/1001330009 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1540474 we are not using it for the model
# There were nulls in TRLH3/1002170018 we are not using it for the model
# There were nulls in 4371-5795 we are not using it for the model
# There were nulls in 4340-5649 we are not using it for the model
# There were nulls in 1535-1678 we are not using it for the model
# There were nulls in TRLH1/1000270110 we are not using it for the model
# There were nulls in TRLH1/1002680095 we are not using it for the model
# There were nulls in 5996-7409 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1083244 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440595 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1810417 we are not using it for the model
# There were nulls in TRLH1/1002100143 we are not using it for the model
# There were nulls in ESPORTSTMNT06/731603 we are not using it for the model
# There were nulls in ESPORTSTMNT06/290056 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1997190 we are not using it for the model
# There were nulls in TRLH1/1001260071 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2005589 we are not using it for the model
# There were nulls in 3361-4182 we are not using it for the model
# There were nulls in 3632-4590 we are not using it for the model
# There were nulls in TRLH1/1000100138 we are not using it for the model
# There were nulls in TRLH3/1000100081 we are not using it for the model
# There were nulls in ESPORTSTMNT06/260104 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1034081 we are not using it for the model
# There were nulls in 4312-5451 we are not using it for the model
# There were nulls in TRLH2/2002300237 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1760458 we are not using it for the model
# There were nulls in TRLH1/1000160193 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1412957 we are not using it for the model
# There were nulls in 7328-9801 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1770074 we are not using it for the model
# There were nulls in 7978-10885 we are not using it for the model
# There were nulls in 3567-4405 we are not using it for the model
# There were nulls in TRLH3/1001990156 we are not using it for the model
# There were nulls in TRLH3/1001690146 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2210369 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1305613 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1295837 we are not using it for the model
# There were nulls in 184-491 we are not using it for the model
# There were nulls in 3675-4676 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440596 we are not using it for the model
# There were nulls in TRLH3/1002210159 we are not using it for the model
# There were nulls in 2720-2812 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1291972 we are not using it for the model
# There were nulls in TRKR1/1130367 we are not using it for the model
# There were nulls in 4929-6318 we are not using it for the model
# There were nulls in TRKR1/1120613 we are not using it for the model
# There were nulls in 3618-4553 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2135624 we are not using it for the model
# There were nulls in TRLH1/1002250138 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1041162 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1074545 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1430694 we are not using it for the model
# There were nulls in 5398-6652 we are not using it for the model
# There were nulls in TRLH1/1002130236 we are not using it for the model
# There were nulls in TRKR1/1170492 we are not using it for the model
# There were nulls in ESPORTSTMNT06/170093 we are not using it for the model
# There were nulls in TRLH3/1001020120 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1013228 we are not using it for the model
# There were nulls in TRLH3/1002210070 we are not using it for the model
# There were nulls in 3569-4409 we are not using it for the model
# There were nulls in TRLH3/1001730080 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1881292 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1403191 we are not using it for the model
# There were nulls in 6601-8341 we are not using it for the model
# There were nulls in 2956-3414 we are not using it for the model
# There were nulls in 154-370 we are not using it for the model
# There were nulls in TRKR1/960304 we are not using it for the model
# There were nulls in ESPORTSTMNT06/771203 we are not using it for the model
# There were nulls in ESPORTSTMNT04/910257 we are not using it for the model
# There were nulls in 767-882 we are not using it for the model
# There were nulls in TRLH1/1000090059 we are not using it for the model
# There were nulls in 8104-11255 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2072234 we are not using it for the model
# There were nulls in TRKR1/1020467 we are not using it for the model
# There were nulls in ESPORTSTMNT06/90738 we are not using it for the model
# There were nulls in TRLH3/1002000034 we are not using it for the model
# There were nulls in TRLH1/1002710252 we are not using it for the model
# There were nulls in TRLH1/1001540022 we are not using it for the model
# There were nulls in 4356-5748 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2076146 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2075873 we are not using it for the model
# There were nulls in TRLH1/1001770289 we are not using it for the model
# There were nulls in 7989-10940 we are not using it for the model
# There were nulls in ESPORTSTMNT02_1937320 we are not using it for the model
# There were nulls in TRLH3/1001700101 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1324190 we are not using it for the model
# There were nulls in 6234-8028 we are not using it for the model
# There were nulls in TRLH1/1001670111 we are not using it for the model
# There were nulls in 794-976 we are not using it for the model
# There were nulls in TRLH3/1001730035 we are not using it for the model
# There were nulls in 4083-5272 we are not using it for the model
# There were nulls in ESPORTSTMNT06/772325 we are not using it for the model
# There were nulls in TRLH1/1002230068 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1074495 we are not using it for the model
# There were nulls in TRLH1/1002300057 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440492 we are not using it for the model
# There were nulls in 7979-10893 we are not using it for the model
# There were nulls in TRLH3/1002540168 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2074833 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610806 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1754590 we are not using it for the model
# There were nulls in 6066-7548 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1020780 we are not using it for the model
# There were nulls in TRLH1/1000130026 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1821490 we are not using it for the model
# There were nulls in TRLH1/1001860031 we are not using it for the model
# There were nulls in ESPORTSTMNT06/601085 we are not using it for the model
# There were nulls in 791-970 we are not using it for the model
# There were nulls in TRLH1/1002650174 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2007485 we are not using it for the model
# There were nulls in TRLH1/1001280062 we are not using it for the model
# There were nulls in TRLH1/1000250065 we are not using it for the model
# There were nulls in TRLH1/1001110014 we are not using it for the model
# There were nulls in 772-894 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2148222 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1395817 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1325904 we are not using it for the model
# There were nulls in 6245-8110 we are not using it for the model
# There were nulls in TRLH3/1002720016 we are not using it for the model
# There were nulls in 5992-7398 we are not using it for the model
# There were nulls in ESPORTSTMNT06/50542 we are not using it for the model
# There were nulls in 6960-9535 we are not using it for the model
# There were nulls in 3548-4358 we are not using it for the model
# There were nulls in 7316-9722 we are not using it for the model
# There were nulls in TRLH3/1000210089 we are not using it for the model
# There were nulls in TRKR1/920462 we are not using it for the model
# There were nulls in 2699-2707 we are not using it for the model
# There were nulls in TRKR1/1040036 we are not using it for the model
# There were nulls in TRKR1/1010056 we are not using it for the model
# There were nulls in ESPORTSTMNT06/140045 we are not using it for the model
# There were nulls in TRLH3/1002390027 we are not using it for the model
# There were nulls in ESPORTSTMNT05_2070811 we are not using it for the model
# There were nulls in 1564-1921 we are not using it for the model
# There were nulls in 1101-1305 we are not using it for the model
# There were nulls in TRKR1/1010377 we are not using it for the model
# There were nulls in TRKR1/1160545 we are not using it for the model
# There were nulls in TRKR1/1150112 we are not using it for the model
# There were nulls in 7976-10869 we are not using it for the model
# There were nulls in FRA1TMNT1/390150 we are not using it for the model
# There were nulls in ESPORTSTMNT06/591358 we are not using it for the model
# There were nulls in 2987-3692 we are not using it for the model
# There were nulls in 3607-4527 we are not using it for the model
# There were nulls in ESPORTSTMNT06/130528 we are not using it for the model
# There were nulls in 6058-7507 we are not using it for the model
# There were nulls in ESPORTSTMNT06/330640 we are not using it for the model
# There were nulls in TRLH3/1000240056 we are not using it for the model
# There were nulls in 6625-8518 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1090924 we are not using it for the model
# There were nulls in TRKR1/950043 we are not using it for the model
# There were nulls in 2955-3411 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1800222 we are not using it for the model
# There were nulls in ESPORTSTMNT04/990733 we are not using it for the model
# There were nulls in ESPORTSTMNT06/780158 we are not using it for the model
# There were nulls in TRLH3/1001980235 we are not using it for the model
# There were nulls in TRKR1/950271 we are not using it for the model
# There were nulls in ESPORTSTMNT06/270417 we are not using it for the model
# There were nulls in TRLH1/1001550113 we are not using it for the model
# There were nulls in TRKR1/1180684 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1510554 we are not using it for the model
# There were nulls in 2074-2110 we are not using it for the model
# There were nulls in 4075-4709 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1826003 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1305601 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1720742 we are not using it for the model
# There were nulls in TRLH2/2002300190 we are not using it for the model
# There were nulls in TRLH1/1002470057 we are not using it for the model
# There were nulls in ESPORTSTMNT06/60593 we are not using it for the model
# There were nulls in 832-1201 we are not using it for the model
# There were nulls in 6919-9228 we are not using it for the model
# There were nulls in 4924-6258 we are not using it for the model
# There were nulls in ESPORTSTMNT06/300604 we are not using it for the model
# There were nulls in 6206-7822 we are not using it for the model
# There were nulls in 7332-9824 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1101238 we are not using it for the model
# There were nulls in 5439-7126 we are not using it for the model
# There were nulls in TRLH1/1000270144 we are not using it for the model
# There were nulls in 832-1202 we are not using it for the model
# There were nulls in 6220-7924 we are not using it for the model
# There were nulls in TRLH3/1001190025 we are not using it for the model
# There were nulls in TRLH3/1001050209 we are not using it for the model
# There were nulls in 6044-7468 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1310889 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1155853 we are not using it for the model
# There were nulls in TRLH1/1002450017 we are not using it for the model
# There were nulls in TRLH1/1002200043 we are not using it for the model
# There were nulls in TREU/1000530522 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1105297 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2076533 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1413045 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1384878 we are not using it for the model
# There were nulls in WMC2TMNT1/290040 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2147506 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1110253 we are not using it for the model
# There were nulls in 7302-9632 we are not using it for the model
# There were nulls in TRLH1/1000240186 we are not using it for the model
# There were nulls in 6613-8427 we are not using it for the model
# There were nulls in ESPORTSTMNT04_1810311 we are not using it for the model
# There were nulls in TRKR1/1140718 we are not using it for the model
# There were nulls in 4322-5499 we are not using it for the model
# There were nulls in TRLH3/1002180080 we are not using it for the model
# There were nulls in TRLH1/1002270094 we are not using it for the model
# There were nulls in TRLH3/1001950051 we are not using it for the model
# There were nulls in ESPORTSTMNT02/980572 we are not using it for the model
# There were nulls in TRLH3/1001200090 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610520 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1530299 we are not using it for the model
# There were nulls in TRLH3/1000230027 we are not using it for the model
# There were nulls in TRLH1/1000340092 we are not using it for the model
# There were nulls in 6630-8565 we are not using it for the model
# There were nulls in TRLH1/1002440106 we are not using it for the model
# There were nulls in TRLH3/1001930103 we are not using it for the model
# There were nulls in ESPORTSTMNT06/720646 we are not using it for the model
# There were nulls in 781-931 we are not using it for the model
# There were nulls in 3360-4161 we are not using it for the model
# There were nulls in 3358-4080 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1112246 we are not using it for the model
# There were nulls in 5385-6543 we are not using it for the model
# There were nulls in TRKR1/910363 we are not using it for the model
# There were nulls in TRKR1/1070150 we are not using it for the model
# There were nulls in ESPORTSTMNT06/740542 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1734320 we are not using it for the model
# There were nulls in 2943-3334 we are not using it for the model
# There were nulls in 3023-3957 we are not using it for the model
# There were nulls in TRKR1/1070625 we are not using it for the model
# There were nulls in 7628-10419 we are not using it for the model
# There were nulls in TRLH3/1002590070 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1060904 we are not using it for the model
# There were nulls in TRLH1/1000290063 we are not using it for the model
# There were nulls in TRLH1/1000300139 we are not using it for the model
# There were nulls in 2946-3348 we are not using it for the model
# There were nulls in 3029-4008 we are not using it for the model
# There were nulls in TRLH3/1002020128 we are not using it for the model
# There were nulls in TRLH1/1001370017 we are not using it for the model
# There were nulls in ESPORTSTMNT06/250623 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40517 we are not using it for the model
# There were nulls in 166-424 we are not using it for the model
# There were nulls in TRLH1/1002480157 we are not using it for the model
# There were nulls in TRLH1/1002040269 we are not using it for the model
# There were nulls in 756-806 we are not using it for the model
# There were nulls in 5377-6499 we are not using it for the model
# There were nulls in 4335-5588 we are not using it for the model
# There were nulls in 6604-8362 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1294710 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1405624 we are not using it for the model
# There were nulls in 3638-4662 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1091379 we are not using it for the model
# There were nulls in 749-792 we are not using it for the model
# There were nulls in 6128-7764 we are not using it for the model
# ...
# There were nulls in ESPORTSTMNT02/1294655 we are not using it for the model
# There were nulls in TRLH1/1001540048 we are not using it for the model
# There were nulls in TRLH1/1001550183 we are not using it for the model
# There were nulls in ESPORTSTMNT02_1960276 we are not using it for the model
# There were nulls in 4894-6101 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1080561 we are not using it for the model
# There were nulls in ESPORTSTMNT06/772641 we are not using it for the model
# There were nulls in 3013-3905 we are not using it for the model
# There were nulls in TRLH1/1000070386 we are not using it for the model
# There were nulls in ESPORTSTMNT04/890870 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2067610 we are not using it for the model
# There were nulls in ESPORTSTMNT05_1981340 we are not using it for the model
# There were nulls in ESPORTSTMNT06/330964 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1082183 we are not using it for the model
# There were nulls in 2971-3544 we are not using it for the model
# There were nulls in 6208-7827 we are not using it for the model
# There were nulls in TRLH3/1000310123 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1100411 we are not using it for the model
# There were nulls in TRLH3/1002390037 we are not using it for the model
# There were nulls in 3620-4557 we are not using it for the model
# There were nulls in ESPORTSTMNT02_1937234 we are not using it for the model
# There were nulls in 7363-9962 we are not using it for the model
# There were nulls in 779-924 we are not using it for the model
# There were nulls in TRLH3/1002590163 we are not using it for the model
# There were nulls in TRLH3/1001700085 we are not using it for the model
# There were nulls in TRLH1/1002620033 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1395870 we are not using it for the model
# There were nulls in TRLH3/1001110069 we are not using it for the model
# There were nulls in 2611-2434 we are not using it for the model
# There were nulls in TRLH3/1002450133 we are not using it for the model
# There were nulls in 2150-2121 we are not using it for the model
# There were nulls in 7309-9683 we are not using it for the model
# There were nulls in 6602-8351 we are not using it for the model
# There were nulls in ESPORTSTMNT02_1970528 we are not using it for the model
# There were nulls in 7980-10899 we are not using it for the model
# There were nulls in TRLH1/1002230211 we are not using it for the model
# There were nulls in TRLH3/1002120138 we are not using it for the model
# There were nulls in ESPORTSTMNT02/801111 we are not using it for the model
# There were nulls in TRLH1/1002330093 we are not using it for the model
# There were nulls in 6205-7820 we are not using it for the model
# There were nulls in TRLH1/1002260042 we are not using it for the model
# There were nulls in TRLH3/1001190031 we are not using it for the model
# There were nulls in 1583-2027 we are not using it for the model
# There were nulls in ESPORTSTMNT04/960826 we are not using it for the model
# There were nulls in 6212-7853 we are not using it for the model
# There were nulls in FRA1TMNT1/400362 we are not using it for the model
# There were nulls in TRLH1/1002240015 we are not using it for the model
# There were nulls in TRLH1/1001730138 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1051785 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1086829 we are not using it for the model
# There were nulls in 7313-9712 we are not using it for the model
# There were nulls in 7346-9922 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40584 we are not using it for the model
# There were nulls in TRLH3/1000090045 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1880303 we are not using it for the model
# There were nulls in 6208-7829 we are not using it for the model
# There were nulls in TRLH3/1002020064 we are not using it for the model
# There were nulls in TRLH3/1001590017 we are not using it for the model
# There were nulls in TRLH1/1001370006 we are not using it for the model
# There were nulls in 7645-10548 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1143689 we are not using it for the model
# There were nulls in 2905-3171 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1821519 we are not using it for the model
# There were nulls in 5361-6352 we are not using it for the model
# There were nulls in 6916-9201 we are not using it for the model
# There were nulls in 3623-4563 we are not using it for the model
# There were nulls in WMC2TMNT1/290038 we are not using it for the model
# There were nulls in TRLH1/1002130076 we are not using it for the model
# There were nulls in 131-272 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1430695 we are not using it for the model
# There were nulls in TRLH1/1000290155 we are not using it for the model
# There were nulls in ESPORTSTMNT06/130535 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1024070 we are not using it for the model
# There were nulls in TRLH1/1002660304 we are not using it for the model
# There were nulls in TRLH1/1002070137 we are not using it for the model
# There were nulls in ESPORTSTMNT06/720648 we are not using it for the model
# There were nulls in TRLH3/1001110168 we are not using it for the model
# There were nulls in TRLH1/1000250048 we are not using it for the model
# There were nulls in ESPORTSTMNT06/60897 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2067393 we are not using it for the model
# There were nulls in 2708-2758 we are not using it for the model
# There were nulls in 3576-4426 we are not using it for the model
# There were nulls in TRLH1/1002710167 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1032253 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1413012 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1881056 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1114599 we are not using it for the model
# There were nulls in TRLH3/1001210070 we are not using it for the model
# There were nulls in TRKR1/1080874 we are not using it for the model
# There were nulls in 6080-7580 we are not using it for the model
# There were nulls in 7385-10022 we are not using it for the model
# There were nulls in ESPORTSTMNT06/590204 we are not using it for the model
# There were nulls in 4379-5815 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1880752 we are not using it for the model
# There were nulls in TRLH3/1001690189 we are not using it for the model
# There were nulls in TRLH1/1001770274 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1830518 we are not using it for the model
# There were nulls in 4360-5764 we are not using it for the model
# There were nulls in 157-376 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1014556 we are not using it for the model
# There were nulls in TRLH1/1001040041 we are not using it for the model
# There were nulls in TRLH3/1002650204 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1441716 we are not using it for the model
# There were nulls in TRLH1/1000290202 we are not using it for the model
# There were nulls in TRLH3/1002200097 we are not using it for the model
# There were nulls in 3602-4512 we are not using it for the model
# There were nulls in 3659-4653 we are not using it for the model
# There were nulls in 6231-7999 we are not using it for the model
# There were nulls in 6003-7427 we are not using it for the model
# There were nulls in 5394-6610 we are not using it for the model
# There were nulls in TRLH1/1001280054 we are not using it for the model
# There were nulls in 5399-6663 we are not using it for the model
# There were nulls in 6650-8691 we are not using it for the model
# There were nulls in 7320-9752 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1050551 we are not using it for the model
# There were nulls in 2923-3255 we are not using it for the model
# There were nulls in TRLH1/1002100229 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1041086 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1115146 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1991955 we are not using it for the model
# There were nulls in ESPORTSTMNT04/960767 we are not using it for the model
# There were nulls in 5426-6881 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1032965 we are not using it for the model
# There were nulls in 4793-5857 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1840896 we are not using it for the model
# There were nulls in TRLH1/1001200090 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1031815 we are not using it for the model
# There were nulls in TRLH1/1001030146 we are not using it for the model
# There were nulls in TRLH3/1001140046 we are not using it for the model
# There were nulls in ESPORTSTMNT06/601248 we are not using it for the model
# There were nulls in TRLH1/1002090129 we are not using it for the model
# There were nulls in 6128-7761 we are not using it for the model
# There were nulls in TRKR1/1120549 we are not using it for the model
# There were nulls in 1575-1991 we are not using it for the model
# There were nulls in TRLH1/1002090004 we are not using it for the model
# There were nulls in ESPORTSTMNT06/720877 we are not using it for the model
# There were nulls in 2901-3163 we are not using it for the model
# There were nulls in ESPORTSTMNT06/320181 we are not using it for the model
# There were nulls in 7637-10480 we are not using it for the model
# There were nulls in TRLH3/1002200148 we are not using it for the model
# There were nulls in TRLH1/1002120195 we are not using it for the model
# There were nulls in TRLH1/1000170168 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1510545 we are not using it for the model
# There were nulls in TRKR1/990104 we are not using it for the model
# There were nulls in TRLH1/1002130226 we are not using it for the model
# There were nulls in ESPORTSTMNT02_1933520 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1324775 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1094107 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1733942 we are not using it for the model
# There were nulls in TRLH1/1001000054 we are not using it for the model
# There were nulls in TRKR1/1020099 we are not using it for the model
# There were nulls in ESPORTSTMNT06/790603 we are not using it for the model
# There were nulls in 6623-8503 we are not using it for the model
# There were nulls in ESPORTSTMNT06/270653 we are not using it for the model
# There were nulls in TRLH3/1001980175 we are not using it for the model
# There were nulls in TRLH3/1000310139 we are not using it for the model
# There were nulls in 8000-10976 we are not using it for the model
# There were nulls in TRLH3/1002530107 we are not using it for the model
# There were nulls in ESPORTSTMNT06/790672 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1061592 we are not using it for the model
# There were nulls in TRLH3/1001480016 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1386265 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1080616 we are not using it for the model
# There were nulls in 6229-7986 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1310886 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1304739 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1092591 we are not using it for the model
# There were nulls in TRLH3/1002020174 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1160581 we are not using it for the model
# There were nulls in 2607-2433 we are not using it for the model
# There were nulls in TRLH3/1001220027 we are not using it for the model
# There were nulls in 1574-1983 we are not using it for the model
# There were nulls in 2727-2838 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1131673 we are not using it for the model
# There were nulls in 6071-7558 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1342220 we are not using it for the model
# There were nulls in 124-235 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1683151 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2148033 we are not using it for the model
# There were nulls in TRLH3/1001680243 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1421788 we are not using it for the model
# There were nulls in TRLH1/1002280257 we are not using it for the model
# There were nulls in ESPORTSTMNT06/960856 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1021716 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2072623 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1386227 we are not using it for the model
# There were nulls in TRLH3/1002200221 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1165430 we are not using it for the model
# There were nulls in 8022-11091 we are not using it for the model
# There were nulls in ESPORTSTMNT06/21163 we are not using it for the model
# There were nulls in ESPORTSTMNT06/810022 we are not using it for the model
# There were nulls in 3572-4417 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1102211 we are not using it for the model
# There were nulls in TRLH3/1002650062 we are not using it for the model
# There were nulls in 6067-7549 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1282702 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1432486 we are not using it for the model
# There were nulls in TRLH1/1001770324 we are not using it for the model
# There were nulls in 6003-7426 we are not using it for the model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8269a60108b6> in <module>
#       3 nonulls = pd.DataFrame()
#       4 for ids in gameids:
# ----> 5     df = dfuse[dfuse["gameid"]== ids]
#       6     if df.isnull().values.any() == True:
#       7         #don't add to overall df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     241
#     242     elif is_object_dtype(lvalues.dtype):
# --> 243         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     244
#     245     else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      53         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      54     else:
# ---> 55         result = libops.scalar_compare(x.ravel(), y, op)
#      56     return result.reshape(x.shape)
#      57
#
# KeyboardInterrupt:

# %%
#checking gameid's for null values
variables = ["gameid","playername","kills","deaths",'assists','doublekills','triplekills','quadrakills','pentakills','firstbloodkill'
             ,'firstbloodassist','firstbloodvictim','dpm','wpm','goldspent','total cs','minionkills','monsterkills',
             'monsterkillsenemyjungle','goldat15','xpat15','csat15','golddiffat15','xpdiffat15',
             'csdiffat15','killsat15','deathsat15','assistsat15','result']
nulldf = dfuse[variables]

gameids = list(dfuse["gameid"])
gameids = set(gameids)
nonulls = pd.DataFrame()
for ids in gameids:
    nonulldf = nulldf[nulldf["gameid"]== ids]
    if df.isnull().values.any() == True:
        #don't add to overall df
        print("There were nulls in "+ ids + " we are not using it for the model")
    else:
        nonulldf = nonulldf.append(df)
# Out:
# There were nulls in ESPORTSTMNT03_2005839 we are not using it for the model
# There were nulls in ESPORTSTMNT06/721794 we are not using it for the model
# There were nulls in 7385-10021 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2006174 we are not using it for the model
# There were nulls in TRLH1/1001770250 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1013631 we are not using it for the model
# There were nulls in 4906-6127 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1442192 we are not using it for the model
# There were nulls in TRLH3/10107 we are not using it for the model
# There were nulls in 4788-5837 we are not using it for the model
# There were nulls in TRLH3/1001930138 we are not using it for the model
# There were nulls in TRLH3/1002020098 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1830074 we are not using it for the model
# There were nulls in 3629-4578 we are not using it for the model
# There were nulls in 6629-8549 we are not using it for the model
# There were nulls in 5425-6870 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1031095 we are not using it for the model
# There were nulls in 7378-9993 we are not using it for the model
# There were nulls in TRKR1/1130310 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1684020 we are not using it for the model
# There were nulls in TRKR1/1050059 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1403220 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1415502 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1430955 we are not using it for the model
# There were nulls in 2145-2130 we are not using it for the model
# There were nulls in 2921-3249 we are not using it for the model
# There were nulls in 4362-5770 we are not using it for the model
# There were nulls in 4356-5749 we are not using it for the model
# There were nulls in 8001-11083 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1161934 we are not using it for the model
# There were nulls in TRLH1/1001800167 we are not using it for the model
# There were nulls in TRLH3/1001100108 we are not using it for the model
# There were nulls in TRLH3/1002580223 we are not using it for the model
# There were nulls in ESPORTSTMNT06/650517 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1443471 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1332603 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1093354 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1881437 we are not using it for the model
# There were nulls in 1560-1889 we are not using it for the model
# There were nulls in 2699-2706 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40068 we are not using it for the model
# There were nulls in TRLH3/1002110084 we are not using it for the model
# There were nulls in TRLH1/1002040245 we are not using it for the model
# There were nulls in 7646-10552 we are not using it for the model
# There were nulls in TRLH1/1002450088 we are not using it for the model
# There were nulls in 139-288 we are not using it for the model
# There were nulls in TRKR1/1040486 we are not using it for the model
# There were nulls in ESPORTSTMNT04/990770 we are not using it for the model
# There were nulls in TRLH3/20057 we are not using it for the model
# There were nulls in TRKR1/1090602 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1735182 we are not using it for the model
# There were nulls in 1099-1295 we are not using it for the model
# There were nulls in 6008-7439 we are not using it for the model
# There were nulls in TRLH3/1002000202 we are not using it for the model
# There were nulls in TRLH1/1000170158 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1133666 we are not using it for the model
# There were nulls in ESPORTSTMNT06/791000 we are not using it for the model
# There were nulls in 7620-10342 we are not using it for the model
# There were nulls in 5977-7364 we are not using it for the model
# There were nulls in 163-417 we are not using it for the model
# There were nulls in TRLH1/1001790082 we are not using it for the model
# There were nulls in TRLH1/1000110021 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1013217 we are not using it for the model
# There were nulls in TRLH3/1001990157 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1390170 we are not using it for the model
# There were nulls in TRLH1/1002690050 we are not using it for the model
# There were nulls in TRLH3/1001690064 we are not using it for the model
# There were nulls in TRLH1/1002290216 we are not using it for the model
# There were nulls in TRLH3/1002190117 we are not using it for the model
# There were nulls in 754-802 we are not using it for the model
# There were nulls in 4301-5423 we are not using it for the model
# There were nulls in ESPORTSTMNT06/280436 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1170219 we are not using it for the model
# There were nulls in 5423-6861 we are not using it for the model
# There were nulls in 7615-10331 we are not using it for the model
# There were nulls in TRLH3/1000380083 we are not using it for the model
# There were nulls in 7620-10343 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1886731 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1053197 we are not using it for the model
# There were nulls in 4915-6192 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1304391 we are not using it for the model
# There were nulls in 3561-4386 we are not using it for the model
# There were nulls in 6932-9323 we are not using it for the model
# There were nulls in 7367-9970 we are not using it for the model
# There were nulls in ESPORTSTMNT06/140928 we are not using it for the model
# There were nulls in ESPORTSTMNT06/771712 we are not using it for the model
# There were nulls in TRKR1/900224 we are not using it for the model
# There were nulls in TRLH3/1000300088 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1997525 we are not using it for the model
# There were nulls in 7969-10827 we are not using it for the model
# There were nulls in ESPORTSTMNT02/992625 we are not using it for the model
# There were nulls in TRLH1/1002650060 we are not using it for the model
# There were nulls in TRLH1/1002300083 we are not using it for the model
# There were nulls in ESPORTSTMNT04/970306 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1414311 we are not using it for the model
# There were nulls in TRLH3/1000370104 we are not using it for the model
# There were nulls in TRKR1/960069 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1830216 we are not using it for the model
# There were nulls in TRKR1/1170499 we are not using it for the model
# There were nulls in 5390-6585 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1287048 we are not using it for the model
# There were nulls in 4342-5660 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1510206 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1433759 we are not using it for the model
# There were nulls in 2685-2761 we are not using it for the model
# There were nulls in 2593-2341 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1143971 we are not using it for the model
# There were nulls in TRLH1/1000050099 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610224 we are not using it for the model
# There were nulls in 3614-4546 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1997159 we are not using it for the model
# There were nulls in 172-465 we are not using it for the model
# There were nulls in 6660-8770 we are not using it for the model
# There were nulls in 2585-2311 we are not using it for the model
# There were nulls in TRLH1/1002110295 we are not using it for the model
# There were nulls in 3573-4419 we are not using it for the model
# There were nulls in TRLH3/1001700033 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1693567 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1351837 we are not using it for the model
# There were nulls in TRLH1/1002060126 we are not using it for the model
# There were nulls in TRLH3/1001310029 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1031204 we are not using it for the model
# There were nulls in 1568-1942 we are not using it for the model
# There were nulls in ESPORTSTMNT06/250523 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1143404 we are not using it for the model
# There were nulls in 1516-1594 we are not using it for the model
# There were nulls in TRKR1/980066 we are not using it for the model
# There were nulls in 5430-6912 we are not using it for the model
# There were nulls in 4883-6071 we are not using it for the model
# There were nulls in TRLH2/2002300068 we are not using it for the model
# There were nulls in TRLH1/1002120133 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1441795 we are not using it for the model
# There were nulls in TRLH3/1000290172 we are not using it for the model
# There were nulls in 2968-3499 we are not using it for the model
# There were nulls in 2928-3275 we are not using it for the model
# There were nulls in 2617-2553 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1283154 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1724893 we are not using it for the model
# There were nulls in 6077-7574 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1091316 we are not using it for the model
# There were nulls in 3648-4629 we are not using it for the model
# There were nulls in 6598-8313 we are not using it for the model
# There were nulls in 1530-1669 we are not using it for the model
# There were nulls in TRLH3/1002210093 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1410145 we are not using it for the model
# There were nulls in 8093-11147 we are not using it for the model
# There were nulls in 1580-2002 we are not using it for the model
# There were nulls in 8109-11287 we are not using it for the model
# There were nulls in ESPORTSTMNT02/801119 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1294784 we are not using it for the model
# There were nulls in TRKR1/1040527 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1220728 we are not using it for the model
# There were nulls in TRLH1/1000120065 we are not using it for the model
# There were nulls in 7346-9925 we are not using it for the model
# There were nulls in TRLH3/1000210110 we are not using it for the model
# There were nulls in TRLH1/1001730132 we are not using it for the model
# There were nulls in TRLH1/1002270064 we are not using it for the model
# There were nulls in ESPORTSTMNT04/890254 we are not using it for the model
# There were nulls in 6955-9504 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1120173 we are not using it for the model
# There were nulls in TRLH1/1001560015 we are not using it for the model
# There were nulls in 5406-6701 we are not using it for the model
# There were nulls in TRLH1/1002330110 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40515 we are not using it for the model
# There were nulls in TRLH1/1002120319 we are not using it for the model
# There were nulls in ESPORTSTMNT06/730277 we are not using it for the model
# There were nulls in 6934-9344 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1060844 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1022932 we are not using it for the model
# There were nulls in TRLH1/1002270122 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1693626 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1996296 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1433058 we are not using it for the model
# There were nulls in 6658-8749 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1271091 we are not using it for the model
# There were nulls in TRLH1/1001030110 we are not using it for the model
# There were nulls in 6004-7428 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1831534 we are not using it for the model
# There were nulls in ESPORTSTMNT06/761971 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1000799 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1150490 we are not using it for the model
# There were nulls in TRLH1/1001790086 we are not using it for the model
# There were nulls in 3547-4357 we are not using it for the model
# There were nulls in 777-902 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1880170 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1816080 we are not using it for the model
# There were nulls in 3019-3949 we are not using it for the model
# There were nulls in 1591-2054 we are not using it for the model
# There were nulls in TRLH3/1000210052 we are not using it for the model
# There were nulls in 7315-9720 we are not using it for the model
# There were nulls in TRLH1/1001260045 we are not using it for the model
# There were nulls in ESPORTSTMNT06/620580 we are not using it for the model
# There were nulls in 2902-3164 we are not using it for the model
# There were nulls in TRLH1/1002670235 we are not using it for the model
# There were nulls in TRLH3/1002710036 we are not using it for the model
# There were nulls in 6660-8769 we are not using it for the model
# There were nulls in 3640-4611 we are not using it for the model
# There were nulls in 7358-9953 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1400896 we are not using it for the model
# There were nulls in 2917-3225 we are not using it for the model
# There were nulls in TRLH1/1001110098 we are not using it for the model
# There were nulls in TRLH1/1001740214 we are not using it for the model
# There were nulls in 1580-2003 we are not using it for the model
# There were nulls in TRLH1/1002470068 we are not using it for the model
# There were nulls in 2972-3545 we are not using it for the model
# There were nulls in TRKR1/1110331 we are not using it for the model
# There were nulls in 6252-8158 we are not using it for the model
# There were nulls in TRLH3/1001290055 we are not using it for the model
# There were nulls in 4081-5266 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1824054 we are not using it for the model
# There were nulls in TRLH1/1002490013 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1683767 we are not using it for the model
# There were nulls in 6241-8068 we are not using it for the model
# There were nulls in 3000-3805 we are not using it for the model
# There were nulls in TRLH3/1001020233 we are not using it for the model
# There were nulls in TRKR1/750688 we are not using it for the model
# There were nulls in TRLH3/1001180186 we are not using it for the model
# There were nulls in TRLH1/1001370028 we are not using it for the model
# There were nulls in 5370-6422 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1041084 we are not using it for the model
# There were nulls in 7982-10908 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1140505 we are not using it for the model
# There were nulls in 6258-8210 we are not using it for the model
# There were nulls in 5422-6850 we are not using it for the model
# There were nulls in TRLH3/1000300120 we are not using it for the model
# There were nulls in 6127-7752 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1144927 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1894761 we are not using it for the model
# There were nulls in TRLH3/1001900079 we are not using it for the model
# There were nulls in TRLH1/1001770141 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1250170 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1840955 we are not using it for the model
# There were nulls in TRLH3/1002020028 we are not using it for the model
# There were nulls in 4281-5377 we are not using it for the model
# There were nulls in 3631-4586 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1043122 we are not using it for the model
# There were nulls in TRLH3/1001580074 we are not using it for the model
# There were nulls in 6009-7441 we are not using it for the model
# There were nulls in WMC2TMNT1/290059 we are not using it for the model
# There were nulls in TRLH1/1002050161 we are not using it for the model
# There were nulls in 1536-1758 we are not using it for the model
# There were nulls in 8099-11205 we are not using it for the model
# There were nulls in TRKR1/1150702 we are not using it for the model
# There were nulls in TRLH1/1001400027 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2055160 we are not using it for the model
# There were nulls in 6683-8852 we are not using it for the model
# There were nulls in ESPORTSTMNT06/581069 we are not using it for the model
# There were nulls in 2951-3396 we are not using it for the model
# There were nulls in TRLH3/1001940150 we are not using it for the model
# There were nulls in TRLH3/1001700214 we are not using it for the model
# There were nulls in ESPORTSTMNT06/240148 we are not using it for the model
# There were nulls in ESPORTSTMNT06/750636 we are not using it for the model
# There were nulls in 8099-11206 we are not using it for the model
# There were nulls in 4931-6337 we are not using it for the model
# There were nulls in TRLH1/1001830086 we are not using it for the model
# There were nulls in 2694-2684 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1113147 we are not using it for the model
# There were nulls in 2988-3710 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440690 we are not using it for the model
# There were nulls in TRLH1/1002670210 we are not using it for the model
# There were nulls in TRLH1/1001730209 we are not using it for the model
# There were nulls in 7990-10941 we are not using it for the model
# There were nulls in 5376-6496 we are not using it for the model
# There were nulls in 760-851 we are not using it for the model
# There were nulls in 7664-10700 we are not using it for the model
# There were nulls in TRLH1/1002100142 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1691645 we are not using it for the model
# There were nulls in TRKR1/1140712 we are not using it for the model
# There were nulls in 4790-5845 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1170778 we are not using it for the model
# There were nulls in TRKR1/920063 we are not using it for the model
# There were nulls in 3009-3867 we are not using it for the model
# There were nulls in 2726-2834 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1673719 we are not using it for the model
# There were nulls in ESPORTSTMNT06/70439 we are not using it for the model
# There were nulls in 4790-5844 we are not using it for the model
# There were nulls in 6923-9255 we are not using it for the model
# There were nulls in TRLH3/1001590043 we are not using it for the model
# There were nulls in TRKR1/1100490 we are not using it for the model
# There were nulls in TRLH3/1001690079 we are not using it for the model
# There were nulls in 3641-4613 we are not using it for the model
# There were nulls in TRKR1/1080796 we are not using it for the model
# There were nulls in 4921-6241 we are not using it for the model
# There were nulls in 4889-6087 we are not using it for the model
# There were nulls in ESPORTSTMNT06/970740 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1820496 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1405442 we are not using it for the model
# There were nulls in TRLH1/1001330012 we are not using it for the model
# There were nulls in TRKR1/1150638 we are not using it for the model
# There were nulls in 1518-1605 we are not using it for the model
# There were nulls in TRLH3/1002040107 we are not using it for the model
# There were nulls in TRLH1/1002250185 we are not using it for the model
# There were nulls in ESPORTSTMNT06/811856 we are not using it for the model
# There were nulls in TRLH3/1001020112 we are not using it for the model
# There were nulls in TRLH1/30030 we are not using it for the model
# There were nulls in 182-486 we are not using it for the model
# There were nulls in 7351-9938 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1128226 we are not using it for the model
# There were nulls in TRLH1/1001690098 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1414788 we are not using it for the model
# There were nulls in TRLH1/1001670110 we are not using it for the model
# There were nulls in TRLH3/1001930127 we are not using it for the model
# There were nulls in ESPORTSTMNT06/551568 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1286938 we are not using it for the model
# There were nulls in 4331-5580 we are not using it for the model
# There were nulls in 3017-3925 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1032986 we are not using it for the model
# There were nulls in 130-270 we are not using it for the model
# There were nulls in 4340-5647 we are not using it for the model
# There were nulls in 138-287 we are not using it for the model
# There were nulls in 8016-11056 we are not using it for the model
# There were nulls in 6595-8287 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1411500 we are not using it for the model
# There were nulls in TRLH1/1000170101 we are not using it for the model
# There were nulls in 6700-8960 we are not using it for the model
# There were nulls in TRLH3/1002150241 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1694012 we are not using it for the model
# There were nulls in 2949-3387 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1160590 we are not using it for the model
# There were nulls in 7375-9979 we are not using it for the model
# There were nulls in TRLH3/1002620188 we are not using it for the model
# There were nulls in TRLH1/1001070013 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2147528 we are not using it for the model
# There were nulls in 2577-2266 we are not using it for the model
# There were nulls in TRKR1/1000116 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1441108 we are not using it for the model
# There were nulls in 2713-2783 we are not using it for the model
# There were nulls in TRLH1/1002710235 we are not using it for the model
# There were nulls in TRKR1/910486 we are not using it for the model
# There were nulls in TRLH1/1001090051 we are not using it for the model
# There were nulls in 6650-8690 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1691701 we are not using it for the model
# There were nulls in TRKR1/950363 we are not using it for the model
# There were nulls in 1589-2050 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1170233 we are not using it for the model
# There were nulls in TRLH3/1001540010 we are not using it for the model
# There were nulls in 2720-2810 we are not using it for the model
# There were nulls in TRLH1/1001250106 we are not using it for the model
# There were nulls in 4331-5576 we are not using it for the model
# There were nulls in 5985-7382 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1292006 we are not using it for the model
# There were nulls in 6261-8232 we are not using it for the model
# There were nulls in ESPORTSTMNT06/641682 we are not using it for the model
# There were nulls in ESPORTSTMNT06/300758 we are not using it for the model
# There were nulls in 1511-1563 we are not using it for the model
# There were nulls in ESPORTSTMNT06/550432 we are not using it for the model
# There were nulls in TRLH3/1001570094 we are not using it for the model
# There were nulls in TRLH3/1002620168 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1132087 we are not using it for the model
# There were nulls in 3597-4501 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1764144 we are not using it for the model
# There were nulls in TRLH3/1001530089 we are not using it for the model
# There were nulls in TRLH3/1002360057 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1560343 we are not using it for the model
# There were nulls in TRLH3/1002410035 we are not using it for the model
# There were nulls in 6606-8373 we are not using it for the model
# There were nulls in TRLH3/1001220050 we are not using it for the model
# There were nulls in 5401-6683 we are not using it for the model
# There were nulls in TRLH3/1001240051 we are not using it for the model
# There were nulls in TRLH3/1000110046 we are not using it for the model
# There were nulls in ESPORTSTMNT06/130222 we are not using it for the model
# There were nulls in 784-936 we are not using it for the model
# There were nulls in TRLH1/1001810068 we are not using it for the model
# There were nulls in TRLH1/1000070277 we are not using it for the model
# There were nulls in 3000-3807 we are not using it for the model
# There were nulls in TRLH1/1000220134 we are not using it for the model
# There were nulls in TRLH1/1002040392 we are not using it for the model
# There were nulls in ESPORTSTMNT06/341202 we are not using it for the model
# There were nulls in 6254-8181 we are not using it for the model
# There were nulls in 1507-1544 we are not using it for the model
# There were nulls in TRLH1/1002650062 we are not using it for the model
# There were nulls in 4350-5713 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1240457 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1011098 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1810385 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1415705 we are not using it for the model
# There were nulls in 4361-5768 we are not using it for the model
# There were nulls in 6045-7470 we are not using it for the model
# There were nulls in TRLH1/1002290272 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1033795 we are not using it for the model
# There were nulls in TRLH3/1001320023 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1436582 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1293319 we are not using it for the model
# There were nulls in 7677-10803 we are not using it for the model
# There were nulls in 6044-7469 we are not using it for the model
# There were nulls in TRLH1/1001560025 we are not using it for the model
# There were nulls in 6911-9186 we are not using it for the model
# There were nulls in 6128-7760 we are not using it for the model
# There were nulls in ESPORTSTMNT05_2060409 we are not using it for the model
# There were nulls in TRKR1/1040460 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1293964 we are not using it for the model
# There were nulls in 5986-7384 we are not using it for the model
# There were nulls in TRLH3/1001090135 we are not using it for the model
# There were nulls in TRLH1/1001770122 we are not using it for the model
# There were nulls in ESPORTSTMNT06/360276 we are not using it for the model
# There were nulls in TRLH3/1000040088 we are not using it for the model
# There were nulls in ESPORTSTMNT06/761293 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1412111 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1302635 we are not using it for the model
# There were nulls in TRLH3/1002220154 we are not using it for the model
# There were nulls in TRLH4/1002060073 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1306406 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2067212 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1332241 we are not using it for the model
# There were nulls in 2696-2697 we are not using it for the model
# There were nulls in TRLH1/1002310068 we are not using it for the model
# There were nulls in 2703-2715 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1141004 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1334858 we are not using it for the model
# There were nulls in 2708-2757 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1831202 we are not using it for the model
# There were nulls in 4380-5818 we are not using it for the model
# There were nulls in TRKR1/1130229 we are not using it for the model
# There were nulls in TRKR1/1130274 we are not using it for the model
# There were nulls in 6963-9562 we are not using it for the model
# There were nulls in TRLH1/1002310217 we are not using it for the model
# There were nulls in 4373-5800 we are not using it for the model
# There were nulls in TRLH1/1001040154 we are not using it for the model
# There were nulls in 4283-5383 we are not using it for the model
# There were nulls in 2960-3436 we are not using it for the model
# There were nulls in FRA1TMNT1/410318 we are not using it for the model
# There were nulls in ESPORTSTMNT06/551204 we are not using it for the model
# There were nulls in TRLH1/1000270128 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1414874 we are not using it for the model
# There were nulls in 4274-5361 we are not using it for the model
# There were nulls in 4289-5396 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40205 we are not using it for the model
# There were nulls in TRKR1/1000316 we are not using it for the model
# There were nulls in WMC2TMNT1/290073 we are not using it for the model
# There were nulls in 2926-3265 we are not using it for the model
# There were nulls in TRLH1/1001090100 we are not using it for the model
# There were nulls in TRLH3/1001530171 we are not using it for the model
# There were nulls in TRLH3/1001160051 we are not using it for the model
# There were nulls in 7358-9951 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1430676 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1023006 we are not using it for the model
# There were nulls in ESPORTSTMNT05_2070823 we are not using it for the model
# There were nulls in TRLH1/1001330009 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1540474 we are not using it for the model
# There were nulls in TRLH3/1002170018 we are not using it for the model
# There were nulls in 4371-5795 we are not using it for the model
# There were nulls in 4340-5649 we are not using it for the model
# There were nulls in 1535-1678 we are not using it for the model
# There were nulls in TRLH1/1000270110 we are not using it for the model
# There were nulls in TRLH1/1002680095 we are not using it for the model
# There were nulls in 5996-7409 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1083244 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440595 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1810417 we are not using it for the model
# There were nulls in TRLH1/1002100143 we are not using it for the model
# There were nulls in ESPORTSTMNT06/731603 we are not using it for the model
# There were nulls in ESPORTSTMNT06/290056 we are not using it for the model
# There were nulls in ESPORTSTMNT03_1997190 we are not using it for the model
# There were nulls in TRLH1/1001260071 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2005589 we are not using it for the model
# There were nulls in 3361-4182 we are not using it for the model
# There were nulls in 3632-4590 we are not using it for the model
# There were nulls in TRLH1/1000100138 we are not using it for the model
# There were nulls in TRLH3/1000100081 we are not using it for the model
# There were nulls in ESPORTSTMNT06/260104 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1034081 we are not using it for the model
# There were nulls in 4312-5451 we are not using it for the model
# There were nulls in TRLH2/2002300237 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1760458 we are not using it for the model
# There were nulls in TRLH1/1000160193 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1412957 we are not using it for the model
# There were nulls in 7328-9801 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1770074 we are not using it for the model
# There were nulls in 7978-10885 we are not using it for the model
# There were nulls in 3567-4405 we are not using it for the model
# There were nulls in TRLH3/1001990156 we are not using it for the model
# There were nulls in TRLH3/1001690146 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2210369 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1305613 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1295837 we are not using it for the model
# There were nulls in 184-491 we are not using it for the model
# There were nulls in 3675-4676 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440596 we are not using it for the model
# There were nulls in TRLH3/1002210159 we are not using it for the model
# There were nulls in 2720-2812 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1291972 we are not using it for the model
# There were nulls in TRKR1/1130367 we are not using it for the model
# There were nulls in 4929-6318 we are not using it for the model
# There were nulls in TRKR1/1120613 we are not using it for the model
# There were nulls in 3618-4553 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2135624 we are not using it for the model
# There were nulls in TRLH1/1002250138 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1041162 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1074545 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1430694 we are not using it for the model
# There were nulls in 5398-6652 we are not using it for the model
# There were nulls in TRLH1/1002130236 we are not using it for the model
# There were nulls in TRKR1/1170492 we are not using it for the model
# There were nulls in ESPORTSTMNT06/170093 we are not using it for the model
# There were nulls in TRLH3/1001020120 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1013228 we are not using it for the model
# There were nulls in TRLH3/1002210070 we are not using it for the model
# There were nulls in 3569-4409 we are not using it for the model
# There were nulls in TRLH3/1001730080 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1881292 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1403191 we are not using it for the model
# There were nulls in 6601-8341 we are not using it for the model
# There were nulls in 2956-3414 we are not using it for the model
# There were nulls in 154-370 we are not using it for the model
# There were nulls in TRKR1/960304 we are not using it for the model
# There were nulls in ESPORTSTMNT06/771203 we are not using it for the model
# There were nulls in ESPORTSTMNT04/910257 we are not using it for the model
# There were nulls in 767-882 we are not using it for the model
# There were nulls in TRLH1/1000090059 we are not using it for the model
# There were nulls in 8104-11255 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2072234 we are not using it for the model
# There were nulls in TRKR1/1020467 we are not using it for the model
# There were nulls in ESPORTSTMNT06/90738 we are not using it for the model
# There were nulls in TRLH3/1002000034 we are not using it for the model
# There were nulls in TRLH1/1002710252 we are not using it for the model
# There were nulls in TRLH1/1001540022 we are not using it for the model
# There were nulls in 4356-5748 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2076146 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2075873 we are not using it for the model
# There were nulls in TRLH1/1001770289 we are not using it for the model
# There were nulls in 7989-10940 we are not using it for the model
# There were nulls in ESPORTSTMNT02_1937320 we are not using it for the model
# There were nulls in TRLH3/1001700101 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1324190 we are not using it for the model
# There were nulls in 6234-8028 we are not using it for the model
# There were nulls in TRLH1/1001670111 we are not using it for the model
# There were nulls in 794-976 we are not using it for the model
# There were nulls in TRLH3/1001730035 we are not using it for the model
# There were nulls in 4083-5272 we are not using it for the model
# There were nulls in ESPORTSTMNT06/772325 we are not using it for the model
# There were nulls in TRLH1/1002230068 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1074495 we are not using it for the model
# There were nulls in TRLH1/1002300057 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440492 we are not using it for the model
# There were nulls in 7979-10893 we are not using it for the model
# There were nulls in TRLH3/1002540168 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2074833 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610806 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1754590 we are not using it for the model
# There were nulls in 6066-7548 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1020780 we are not using it for the model
# There were nulls in TRLH1/1000130026 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1821490 we are not using it for the model
# There were nulls in TRLH1/1001860031 we are not using it for the model
# There were nulls in ESPORTSTMNT06/601085 we are not using it for the model
# There were nulls in 791-970 we are not using it for the model
# There were nulls in TRLH1/1002650174 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2007485 we are not using it for the model
# There were nulls in TRLH1/1001280062 we are not using it for the model
# There were nulls in TRLH1/1000250065 we are not using it for the model
# There were nulls in TRLH1/1001110014 we are not using it for the model
# There were nulls in 772-894 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2148222 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1395817 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1325904 we are not using it for the model
# There were nulls in 6245-8110 we are not using it for the model
# There were nulls in TRLH3/1002720016 we are not using it for the model
# There were nulls in 5992-7398 we are not using it for the model
# There were nulls in ESPORTSTMNT06/50542 we are not using it for the model
# There were nulls in 6960-9535 we are not using it for the model
# There were nulls in 3548-4358 we are not using it for the model
# There were nulls in 7316-9722 we are not using it for the model
# There were nulls in TRLH3/1000210089 we are not using it for the model
# There were nulls in TRKR1/920462 we are not using it for the model
# There were nulls in 2699-2707 we are not using it for the model
# There were nulls in TRKR1/1040036 we are not using it for the model
# There were nulls in TRKR1/1010056 we are not using it for the model
# There were nulls in ESPORTSTMNT06/140045 we are not using it for the model
# There were nulls in TRLH3/1002390027 we are not using it for the model
# There were nulls in ESPORTSTMNT05_2070811 we are not using it for the model
# There were nulls in 1564-1921 we are not using it for the model
# There were nulls in 1101-1305 we are not using it for the model
# There were nulls in TRKR1/1010377 we are not using it for the model
# There were nulls in TRKR1/1160545 we are not using it for the model
# There were nulls in TRKR1/1150112 we are not using it for the model
# There were nulls in 7976-10869 we are not using it for the model
# There were nulls in FRA1TMNT1/390150 we are not using it for the model
# There were nulls in ESPORTSTMNT06/591358 we are not using it for the model
# There were nulls in 2987-3692 we are not using it for the model
# There were nulls in 3607-4527 we are not using it for the model
# There were nulls in ESPORTSTMNT06/130528 we are not using it for the model
# There were nulls in 6058-7507 we are not using it for the model
# There were nulls in ESPORTSTMNT06/330640 we are not using it for the model
# There were nulls in TRLH3/1000240056 we are not using it for the model
# There were nulls in 6625-8518 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1090924 we are not using it for the model
# There were nulls in TRKR1/950043 we are not using it for the model
# There were nulls in 2955-3411 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1800222 we are not using it for the model
# There were nulls in ESPORTSTMNT04/990733 we are not using it for the model
# There were nulls in ESPORTSTMNT06/780158 we are not using it for the model
# There were nulls in TRLH3/1001980235 we are not using it for the model
# There were nulls in TRKR1/950271 we are not using it for the model
# There were nulls in ESPORTSTMNT06/270417 we are not using it for the model
# There were nulls in TRLH1/1001550113 we are not using it for the model
# There were nulls in TRKR1/1180684 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1510554 we are not using it for the model
# There were nulls in 2074-2110 we are not using it for the model
# There were nulls in 4075-4709 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1826003 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1305601 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1720742 we are not using it for the model
# There were nulls in TRLH2/2002300190 we are not using it for the model
# There were nulls in TRLH1/1002470057 we are not using it for the model
# There were nulls in ESPORTSTMNT06/60593 we are not using it for the model
# There were nulls in 832-1201 we are not using it for the model
# There were nulls in 6919-9228 we are not using it for the model
# There were nulls in 4924-6258 we are not using it for the model
# There were nulls in ESPORTSTMNT06/300604 we are not using it for the model
# There were nulls in 6206-7822 we are not using it for the model
# There were nulls in 7332-9824 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1101238 we are not using it for the model
# There were nulls in 5439-7126 we are not using it for the model
# There were nulls in TRLH1/1000270144 we are not using it for the model
# There were nulls in 832-1202 we are not using it for the model
# There were nulls in 6220-7924 we are not using it for the model
# There were nulls in TRLH3/1001190025 we are not using it for the model
# There were nulls in TRLH3/1001050209 we are not using it for the model
# There were nulls in 6044-7468 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1310889 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1155853 we are not using it for the model
# There were nulls in TRLH1/1002450017 we are not using it for the model
# There were nulls in TRLH1/1002200043 we are not using it for the model
# There were nulls in TREU/1000530522 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1105297 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2076533 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1413045 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1384878 we are not using it for the model
# There were nulls in WMC2TMNT1/290040 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2147506 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1110253 we are not using it for the model
# There were nulls in 7302-9632 we are not using it for the model
# There were nulls in TRLH1/1000240186 we are not using it for the model
# There were nulls in 6613-8427 we are not using it for the model
# There were nulls in ESPORTSTMNT04_1810311 we are not using it for the model
# There were nulls in TRKR1/1140718 we are not using it for the model
# There were nulls in 4322-5499 we are not using it for the model
# There were nulls in TRLH3/1002180080 we are not using it for the model
# There were nulls in TRLH1/1002270094 we are not using it for the model
# There were nulls in TRLH3/1001950051 we are not using it for the model
# There were nulls in ESPORTSTMNT02/980572 we are not using it for the model
# There were nulls in TRLH3/1001200090 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610520 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1530299 we are not using it for the model
# There were nulls in TRLH3/1000230027 we are not using it for the model
# There were nulls in TRLH1/1000340092 we are not using it for the model
# There were nulls in 6630-8565 we are not using it for the model
# There were nulls in TRLH1/1002440106 we are not using it for the model
# There were nulls in TRLH3/1001930103 we are not using it for the model
# There were nulls in ESPORTSTMNT06/720646 we are not using it for the model
# There were nulls in 781-931 we are not using it for the model
# There were nulls in 3360-4161 we are not using it for the model
# There were nulls in 3358-4080 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1112246 we are not using it for the model
# There were nulls in 5385-6543 we are not using it for the model
# There were nulls in TRKR1/910363 we are not using it for the model
# There were nulls in TRKR1/1070150 we are not using it for the model
# There were nulls in ESPORTSTMNT06/740542 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1734320 we are not using it for the model
# There were nulls in 2943-3334 we are not using it for the model
# There were nulls in 3023-3957 we are not using it for the model
# There were nulls in TRKR1/1070625 we are not using it for the model
# There were nulls in 7628-10419 we are not using it for the model
# There were nulls in TRLH3/1002590070 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1060904 we are not using it for the model
# There were nulls in TRLH1/1000290063 we are not using it for the model
# There were nulls in TRLH1/1000300139 we are not using it for the model
# There were nulls in 2946-3348 we are not using it for the model
# There were nulls in 3029-4008 we are not using it for the model
# There were nulls in TRLH3/1002020128 we are not using it for the model
# There were nulls in TRLH1/1001370017 we are not using it for the model
# There were nulls in ESPORTSTMNT06/250623 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40517 we are not using it for the model
# There were nulls in 166-424 we are not using it for the model
# There were nulls in TRLH1/1002480157 we are not using it for the model
# There were nulls in TRLH1/1002040269 we are not using it for the model
# There were nulls in 756-806 we are not using it for the model
# There were nulls in 5377-6499 we are not using it for the model
# There were nulls in 4335-5588 we are not using it for the model
# There were nulls in 6604-8362 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1294710 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1405624 we are not using it for the model
# There were nulls in 3638-4662 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1091379 we are not using it for the model
# There were nulls in 749-792 we are not using it for the model
# There were nulls in 6128-7764 we are not using it for the model
# ...
# There were nulls in ESPORTSTMNT02/1092075 we are not using it for the model
# There were nulls in TRLH3/1001720078 we are not using it for the model
# There were nulls in 2719-2808 we are not using it for the model
# There were nulls in TRLH3/30050 we are not using it for the model
# There were nulls in 7381-10003 we are not using it for the model
# There were nulls in TRLH1/30161 we are not using it for the model
# There were nulls in TRLH3/1001570035 we are not using it for the model
# There were nulls in TRLH3/1001240128 we are not using it for the model
# There were nulls in TRLH3/1002210034 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1001151 we are not using it for the model
# There were nulls in 4303-5427 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1129073 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610102 we are not using it for the model
# There were nulls in ESPORTSTMNT02/992686 we are not using it for the model
# There were nulls in TRLH1/1002720040 we are not using it for the model
# There were nulls in 120-225 we are not using it for the model
# There were nulls in 5387-6564 we are not using it for the model
# There were nulls in TRLH1/1000290143 we are not using it for the model
# There were nulls in TRLH1/1002720097 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1440635 we are not using it for the model
# There were nulls in ESPORTSTMNT06/771085 we are not using it for the model
# There were nulls in TRLH3/1002040073 we are not using it for the model
# There were nulls in TRLH3/1000160149 we are not using it for the model
# There were nulls in TRKR1/890077 we are not using it for the model
# There were nulls in 6591-8255 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1887390 we are not using it for the model
# There were nulls in 7971-10833 we are not using it for the model
# There were nulls in 1559-1884 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1415378 we are not using it for the model
# There were nulls in 4352-5738 we are not using it for the model
# There were nulls in TRLH1/1001290018 we are not using it for the model
# There were nulls in 3663-4658 we are not using it for the model
# There were nulls in 8098-11196 we are not using it for the model
# There were nulls in 7648-10570 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1734439 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1051866 we are not using it for the model
# There were nulls in 5432-6948 we are not using it for the model
# There were nulls in 6952-9479 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1101938 we are not using it for the model
# There were nulls in 3008-3865 we are not using it for the model
# There were nulls in ESPORTSTMNT06/270945 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1294908 we are not using it for the model
# There were nulls in 6630-8559 we are not using it for the model
# There were nulls in 1104-1312 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1105294 we are not using it for the model
# There were nulls in TRLH3/1002170159 we are not using it for the model
# There were nulls in TRLH1/1001210134 we are not using it for the model
# There were nulls in 144-319 we are not using it for the model
# There were nulls in TRKR1/1160456 we are not using it for the model
# There were nulls in ESPORTSTMNT06/550374 we are not using it for the model
# There were nulls in 6210-7841 we are not using it for the model
# There were nulls in ESPORTSTMNT04/1480816 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1131400 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1043203 we are not using it for the model
# There were nulls in 1525-1624 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1824058 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1430374 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2076210 we are not using it for the model
# There were nulls in TRLH1/1002070163 we are not using it for the model
# There were nulls in ESPORTSTMNT06/790625 we are not using it for the model
# There were nulls in 3593-4486 we are not using it for the model
# There were nulls in 6623-8502 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2092494 we are not using it for the model
# There were nulls in TRLH1/1002250079 we are not using it for the model
# There were nulls in TRLH1/1001730247 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1090996 we are not using it for the model
# There were nulls in 2993-3744 we are not using it for the model
# There were nulls in FRA1TMNT1/410316 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1880371 we are not using it for the model
# There were nulls in TRLH1/1001230270 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610658 we are not using it for the model
# There were nulls in 5660-7262 we are not using it for the model
# There were nulls in 3001-3818 we are not using it for the model
# There were nulls in TRLH1/1002270052 we are not using it for the model
# There were nulls in 4359-5762 we are not using it for the model
# There were nulls in TRLH3/1001480021 we are not using it for the model
# There were nulls in TRLH1/1001800226 we are not using it for the model
# There were nulls in 4368-5789 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1293807 we are not using it for the model
# There were nulls in TRKR1/1080801 we are not using it for the model
# There were nulls in TRLH1/1001110120 we are not using it for the model
# There were nulls in TRLH1/1002520204 we are not using it for the model
# There were nulls in FRA1TMNT1/390338 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1332659 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1291458 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2007453 we are not using it for the model
# There were nulls in ESPORTSTMNT06/290052 we are not using it for the model
# There were nulls in ESPORTSTMNT06/370288 we are not using it for the model
# There were nulls in 151-362 we are not using it for the model
# There were nulls in 3648-4630 we are not using it for the model
# There were nulls in 1586-2041 we are not using it for the model
# There were nulls in 7384-10016 we are not using it for the model
# There were nulls in 7671-10756 we are not using it for the model
# There were nulls in TRLH3/1001800049 we are not using it for the model
# There were nulls in TRLH3/1001520155 we are not using it for the model
# There were nulls in TRLH1/1001240111 we are not using it for the model
# There were nulls in 810-1110 we are not using it for the model
# There were nulls in 8003-10978 we are not using it for the model
# There were nulls in TRLH1/1002080081 we are not using it for the model
# There were nulls in TRLH1/1001810055 we are not using it for the model
# There were nulls in TRLH3/1002110037 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1286682 we are not using it for the model
# There were nulls in 5987-7387 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1333684 we are not using it for the model
# There were nulls in TRLH1/1002100099 we are not using it for the model
# There were nulls in 4890-6092 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1130786 we are not using it for the model
# There were nulls in TRLH3/1001730051 we are not using it for the model
# There were nulls in TRLH1/1001690096 we are not using it for the model
# There were nulls in TRLH3/1002040071 we are not using it for the model
# There were nulls in ESPORTSTMNT06/30284 we are not using it for the model
# There were nulls in TRLH1/1001800189 we are not using it for the model
# There were nulls in 1524-1623 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1881421 we are not using it for the model
# There were nulls in TRLH1/1001510217 we are not using it for the model
# There were nulls in 4384-5827 we are not using it for the model
# There were nulls in TRKR1/1020465 we are not using it for the model
# There were nulls in 3004-3857 we are not using it for the model
# There were nulls in TRLH3/1001010086 we are not using it for the model
# There were nulls in 1565-1930 we are not using it for the model
# There were nulls in TRLH1/1001670232 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1100458 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2136240 we are not using it for the model
# There were nulls in 2904-3168 we are not using it for the model
# There were nulls in 4901-6117 we are not using it for the model
# There were nulls in TRLH3/1001570095 we are not using it for the model
# There were nulls in TRKR1/890061 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1180210 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1120656 we are not using it for the model
# There were nulls in 3641-4612 we are not using it for the model
# There were nulls in 5414-6786 we are not using it for the model
# There were nulls in 3678-4687 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1883174 we are not using it for the model
# There were nulls in 3625-4567 we are not using it for the model
# There were nulls in 3611-4535 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1040792 we are not using it for the model
# There were nulls in 7305-9659 we are not using it for the model
# There were nulls in TRKR1/1070988 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1824359 we are not using it for the model
# There were nulls in TRLH3/1001070100 we are not using it for the model
# There were nulls in ESPORTSTMNT02_2076330 we are not using it for the model
# There were nulls in 5402-6690 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1115847 we are not using it for the model
# There were nulls in TRLH1/1002040257 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2102050 we are not using it for the model
# There were nulls in 817-1145 we are not using it for the model
# There were nulls in TRLH1/1002040401 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1426113 we are not using it for the model
# There were nulls in TRLH1/1001770071 we are not using it for the model
# There were nulls in TRLH3/1001050166 we are not using it for the model
# There were nulls in TRLH1/1002210113 we are not using it for the model
# There were nulls in TRLH1/1001210113 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1180401 we are not using it for the model
# There were nulls in TRLH3/1001710054 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1750802 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1143995 we are not using it for the model
# There were nulls in TRLH1/1002120028 we are not using it for the model
# There were nulls in TRLH1/1000050213 we are not using it for the model
# There were nulls in 824-1182 we are not using it for the model
# There were nulls in 7667-10724 we are not using it for the model
# There were nulls in TRLH3/1002450137 we are not using it for the model
# There were nulls in ESPORTSTMNT04/990379 we are not using it for the model
# There were nulls in 4312-5450 we are not using it for the model
# There were nulls in ESPORTSTMNT06/180040 we are not using it for the model
# There were nulls in ESPORTSTMNT05_2060688 we are not using it for the model
# There were nulls in TRKR1/1040523 we are not using it for the model
# There were nulls in ESPORTSTMNT06/810035 we are not using it for the model
# There were nulls in 5953-7308 we are not using it for the model
# There were nulls in 6951-9474 we are not using it for the model
# There were nulls in 6605-8363 we are not using it for the model
# There were nulls in TRLH3/1002010154 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1021352 we are not using it for the model
# There were nulls in ESPORTSTMNT02_1936296 we are not using it for the model
# There were nulls in 3005-3859 we are not using it for the model
# There were nulls in TRKR1/1040466 we are not using it for the model
# There were nulls in 2605-2419 we are not using it for the model
# There were nulls in ESPORTSTMNT06/40426 we are not using it for the model
# There were nulls in TRKR1/1100163 we are not using it for the model
# There were nulls in 5996-7408 we are not using it for the model
# There were nulls in 2587-2326 we are not using it for the model
# There were nulls in TRLH3/1002400099 we are not using it for the model
# There were nulls in 7386-10025 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1041882 we are not using it for the model
# There were nulls in ESPORTSTMNT03_2007489 we are not using it for the model
# There were nulls in ESPORTSTMNT06/610634 we are not using it for the model
# There were nulls in 5995-7405 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1682213 we are not using it for the model
# There were nulls in ESPORTSTMNT01_2201262 we are not using it for the model
# There were nulls in ESPORTSTMNT06/90726 we are not using it for the model
# There were nulls in ESPORTSTMNT06/811812 we are not using it for the model
# There were nulls in ESPORTSTMNT06/250658 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1170633 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1414857 we are not using it for the model
# There were nulls in ESPORTSTMNT02/1081687 we are not using it for the model
# There were nulls in TRLH3/1002680066 we are not using it for the model
# There were nulls in ESPORTSTMNT06/60930 we are not using it for the model
# There were nulls in ESPORTSTMNT05/1540409 we are not using it for the model
# There were nulls in TRLH1/1000150052 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1403647 we are not using it for the model
# There were nulls in 4327-5552 we are not using it for the model
# There were nulls in 6244-8101 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1141615 we are not using it for the model
# There were nulls in ESPORTSTMNT06/1310719 we are not using it for the model
# There were nulls in TRLH1/1001730026 we are not using it for the model
# There were nulls in TRLH3/1001090119 we are not using it for the model
# There were nulls in 797-1062 we are not using it for the model
# There were nulls in TRLH1/1002110021 we are not using it for the model
# There were nulls in TRLH3/1002590140 we are not using it for the model
# There were nulls in 4381-5820 we are not using it for the model
# There were nulls in 4080-4789 we are not using it for the model
# There were nulls in TRLH3/1002600164 we are not using it for the model
# There were nulls in ESPORTSTMNT06/761501 we are not using it for the model
# There were nulls in 3632-4588 we are not using it for the model
# There were nulls in ESPORTSTMNT06/50217 we are not using it for the model
# There were nulls in 7633-10449 we are not using it for the model
# There were nulls in 6942-9406 we are not using it for the model
# There were nulls in ESPORTSTMNT01/1131772 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1824365 we are not using it for the model
# There were nulls in ESPORTSTMNT03/1352552 we are not using it for the model
# There were nulls in 2581-2282 we are not using it for the model
# There were nulls in TRLH3/1000140142 we are not using it for the model
# There were nulls in TRLH1/1002290233 we are not using it for the model
# There were nulls in TRLH1/1001280102 we are not using it for the model
# There were nulls in ESPORTSTMNT06_1840487 we are not using it for the model
# There were nulls in TRLH3/1001210235 we are not using it for the model
# There were nulls in 3667-4699 we are not using it for the model
# There were nulls in 1508-1552 we are not using it for the model

# %%
variables = ["kills","deaths",'assists','doublekills','triplekills','quadrakills','pentakills','firstbloodkill'
             ,'firstbloodassist','firstbloodvictim','dpm','wpm','goldspent','total cs','minionkills','monsterkills',
             'monsterkillsenemyjungle','goldat15','xpat15','csat15','golddiffat15','xpdiffat15',
             'csdiffat15','killsat15','deathsat15','assistsat15']
result = "result"

x = dfuse[variables][dfuse["datacompleteness"]== "complete"]
y = dfuse["result"][dfuse["datacompleteness"]== "complete"]

# %%
x
# Out:
#         kills  deaths  assists  doublekills  triplekills  quadrakills  \
# 20          2       1       10          0.0          0.0          0.0
# 21          5       2        8          1.0          1.0          0.0
# 22          2       2       10          0.0          0.0          0.0
# 23          5       2        8          0.0          0.0          0.0
# 24          2       1       11          0.0          0.0          0.0
# ...       ...     ...      ...          ...          ...          ...
# 497469      5       2        3          0.0          0.0          0.0
# 497470      2       4        7          0.0          0.0          0.0
# 497471      2       4        6          0.0          0.0          0.0
# 497472      2       1        6          0.0          0.0          0.0
# 497473      0       2        5          0.0          0.0          0.0
#
#         pentakills  firstbloodkill  firstbloodassist  firstbloodvictim  ...  \
# 20             0.0             0.0               0.0               0.0  ...
# 21             0.0             0.0               0.0               1.0  ...
# 22             0.0             0.0               0.0               0.0  ...
# 23             0.0             0.0               0.0               0.0  ...
# 24             0.0             0.0               0.0               0.0  ...
# ...            ...             ...               ...               ...  ...
# 497469         0.0             0.0               0.0               0.0  ...
# 497470         0.0             0.0               0.0               0.0  ...
# 497471         0.0             0.0               0.0               0.0  ...
# 497472         0.0             0.0               0.0               0.0  ...
# 497473         0.0             0.0               0.0               1.0  ...
#
#         monsterkillsenemyjungle  goldat15  xpat15  csat15  golddiffat15  \
# 20                         14.0    4901.0  5827.0   108.0         445.0
# 21                         57.0    5064.0  5499.0    72.0          59.0
# 22                          1.0    4630.0  6835.0   106.0       -1442.0
# 23                          1.0    6047.0  6239.0   151.0        -343.0
# 24                          2.0    3536.0  3491.0    11.0         310.0
# ...                         ...       ...     ...     ...           ...
# 497469                      0.0    6167.0  7747.0   139.0        1774.0
# 497470                      4.0    4627.0  5302.0    91.0        -901.0
# 497471                      0.0    5114.0  7320.0   139.0        -619.0
# 497472                      0.0    5081.0  5880.0   143.0        -770.0
# 497473                      0.0    3013.0  3472.0    21.0        -765.0
#
#         xpdiffat15  csdiffat15  killsat15  deathsat15  assistsat15
# 20            78.0         6.0        0.0         0.0          1.0
# 21          -836.0       -23.0        0.0         1.0          1.0
# 22         -1116.0       -42.0        0.0         1.0          0.0
# 23          -392.0       -23.0        1.0         0.0          0.0
# 24            -6.0         2.0        0.0         1.0          1.0
# ...            ...         ...        ...         ...          ...
# 497469      1264.0        33.0        2.0         0.0          0.0
# 497470       436.0        -1.0        0.0         1.0          2.0
# 497471      -390.0       -15.0        0.0         1.0          0.0
# 497472       494.0         2.0        0.0         0.0          0.0
# 497473      -690.0         0.0        0.0         2.0          0.0
#
# [97640 rows x 26 columns]

# %%
y
# Out:
# 20        1
# 21        1
# 22        1
# 23        1
# 24        1
#          ..
# 497469    0
# 497470    0
# 497471    0
# 497472    0
# 497473    0
# Name: result, Length: 97640, dtype: int64

# %%
variables = ["kills","deaths",'assists','doublekills','triplekills','quadrakills','pentakills','firstbloodkill'
             ,'firstbloodassist','firstbloodvictim','dpm','wpm','goldspent','total cs','minionkills','monsterkills',
             'monsterkillsenemyjungle','goldat15','xpat15','csat15','golddiffat15','xpdiffat15',
             'csdiffat15','killsat15','deathsat15','assistsat15']


x = nonulldf[variables]
y = dfuse["result"]

# %%
x

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter = 100000)

# fit the model with data
logreg = logreg.fit(x_train,y_train)

#
y_pred=logreg.predict(x_test)
logreg.coef_, logreg.intercept_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-80f0eef1f0a1> in <module>
#       6
#       7 # fit the model with data
# ----> 8 logreg = logreg.fit(x_train,y_train)
#       9
#      10 #
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
logreg.score(x_test,y_test)

# %%
dftest = pd.DataFrame()
dftest["Var"] = variables
dftest
