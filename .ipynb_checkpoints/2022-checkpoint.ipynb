# %% [markdown]
# This File will take the 2022 data and create the

# %%
import pandas as pd 
import numpy as np
import os

# %%
#Use this file path for pc
filepath = r"D:\gradschool\Capstone"
#Use this file path for mac 
#filepath = r"/Users/jacksonjoyner/Desktop/MSBA/Capstone/UseThisData/"
os.chdir(filepath)

# %%
matchdf = pd.read_csv("2022_LoL_esports_match.csv")
matchdf
# Out:
#                       gameid datacompleteness  url  league  year   split  \
# 0      ESPORTSTMNT01_2690210         complete  NaN  LCK CL  2022  Spring
# 1      ESPORTSTMNT01_2690210         complete  NaN  LCK CL  2022  Spring
# 2      ESPORTSTMNT01_2690210         complete  NaN  LCK CL  2022  Spring
# 3      ESPORTSTMNT01_2690210         complete  NaN  LCK CL  2022  Spring
# 4      ESPORTSTMNT01_2690210         complete  NaN  LCK CL  2022  Spring
# ...                      ...              ...  ...     ...   ...     ...
# 61171  ESPORTSTMNT01_2862480         complete  NaN     LCS  2022     NaN
# 61172  ESPORTSTMNT01_2862480         complete  NaN     LCS  2022     NaN
# 61173  ESPORTSTMNT01_2862480         complete  NaN     LCS  2022     NaN
# 61174  ESPORTSTMNT01_2862480         complete  NaN     LCS  2022     NaN
# 61175  ESPORTSTMNT01_2862480         complete  NaN     LCS  2022     NaN
#
#        playoffs                 date  game  patch  ...  opp_csat15  \
# 0             0  2022-01-10 07:44:08     1  12.01  ...       121.0
# 1             0  2022-01-10 07:44:08     1  12.01  ...       100.0
# 2             0  2022-01-10 07:44:08     1  12.01  ...       119.0
# 3             0  2022-01-10 07:44:08     1  12.01  ...       149.0
# 4             0  2022-01-10 07:44:08     1  12.01  ...        21.0
# ...         ...                  ...   ...    ...  ...         ...
# 61171         1  2022-04-24 21:14:20     3  12.06  ...       129.0
# 61172         1  2022-04-24 21:14:20     3  12.06  ...       137.0
# 61173         1  2022-04-24 21:14:20     3  12.06  ...        22.0
# 61174         1  2022-04-24 21:14:20     3  12.06  ...       560.0
# 61175         1  2022-04-24 21:14:20     3  12.06  ...       505.0
#
#       golddiffat15 xpdiffat15 csdiffat15 killsat15 assistsat15 deathsat15  \
# 0            391.0      345.0       14.0       0.0         1.0        0.0
# 1            541.0     -275.0      -11.0       2.0         3.0        2.0
# 2           -475.0      153.0        1.0       0.0         3.0        0.0
# 3           -793.0    -1343.0      -34.0       2.0         1.0        2.0
# 4            443.0     -497.0        7.0       1.0         2.0        2.0
# ...            ...        ...        ...       ...         ...        ...
# 61171        340.0      351.0       29.0       1.0         0.0        1.0
# 61172        217.0      260.0        6.0       0.0         3.0        1.0
# 61173        663.0      198.0        0.0       2.0         1.0        2.0
# 61174      -2087.0    -1242.0      -55.0       5.0         7.0        4.0
# 61175       2087.0     1242.0       55.0       4.0         5.0        5.0
#
#       opp_killsat15 opp_assistsat15 opp_deathsat15
# 0               0.0             1.0            0.0
# 1               0.0             5.0            1.0
# 2               3.0             3.0            2.0
# 3               3.0             3.0            0.0
# 4               0.0             6.0            2.0
# ...             ...             ...            ...
# 61171           2.0             0.0            0.0
# 61172           3.0             1.0            2.0
# 61173           0.0             3.0            1.0
# 61174           4.0             5.0            5.0
# 61175           5.0             7.0            4.0
#
# [61176 rows x 123 columns]

# %%
#this chunck of code will take the longest in the notebook
listid = matchdf['gameid'].tolist()
setid = set(listid)
playerdf = pd.DataFrame()
for item in setid:
    df_new = matchdf[matchdf["gameid"]== item]
    player = df_new.iloc[:10]
    playerdf = playerdf.append(player)

# %%
playerdf
# Out:
#                       gameid datacompleteness  \
# 12468  ESPORTSTMNT02_2554281         complete
# 12469  ESPORTSTMNT02_2554281         complete
# 12470  ESPORTSTMNT02_2554281         complete
# 12471  ESPORTSTMNT02_2554281         complete
# 12472  ESPORTSTMNT02_2554281         complete
# ...                      ...              ...
# 31661       8759-8759_game_2          partial
# 31662       8759-8759_game_2          partial
# 31663       8759-8759_game_2          partial
# 31664       8759-8759_game_2          partial
# 31665       8759-8759_game_2          partial
#
#                                                url league  year   split  \
# 12468                                          NaN  LPLOL  2022  Spring
# 12469                                          NaN  LPLOL  2022  Spring
# 12470                                          NaN  LPLOL  2022  Spring
# 12471                                          NaN  LPLOL  2022  Spring
# 12472                                          NaN  LPLOL  2022  Spring
# ...                                            ...    ...   ...     ...
# 31661  https://lpl.qq.com/es/stats.shtml?bmid=8759    LPL  2022  Spring
# 31662  https://lpl.qq.com/es/stats.shtml?bmid=8759    LPL  2022  Spring
# 31663  https://lpl.qq.com/es/stats.shtml?bmid=8759    LPL  2022  Spring
# 31664  https://lpl.qq.com/es/stats.shtml?bmid=8759    LPL  2022  Spring
# 31665  https://lpl.qq.com/es/stats.shtml?bmid=8759    LPL  2022  Spring
#
#        playoffs                 date  game  patch  ...  opp_csat15  \
# 12468         0  2022-02-02 19:57:52     1  12.02  ...       125.0
# 12469         0  2022-02-02 19:57:52     1  12.02  ...        81.0
# 12470         0  2022-02-02 19:57:52     1  12.02  ...       135.0
# 12471         0  2022-02-02 19:57:52     1  12.02  ...       136.0
# 12472         0  2022-02-02 19:57:52     1  12.02  ...        17.0
# ...         ...                  ...   ...    ...  ...         ...
# 31661         0  2022-02-28 12:06:50     2  12.04  ...         NaN
# 31662         0  2022-02-28 12:06:50     2  12.04  ...         NaN
# 31663         0  2022-02-28 12:06:50     2  12.04  ...         NaN
# 31664         0  2022-02-28 12:06:50     2  12.04  ...         NaN
# 31665         0  2022-02-28 12:06:50     2  12.04  ...         NaN
#
#       golddiffat15 xpdiffat15 csdiffat15 killsat15 assistsat15 deathsat15  \
# 12468        140.0      229.0        9.0       0.0         0.0        0.0
# 12469       -951.0      794.0        2.0       0.0         0.0        0.0
# 12470      -1023.0     -749.0        2.0       0.0         0.0        1.0
# 12471       -555.0     -779.0      -23.0       0.0         0.0        0.0
# 12472       -264.0      175.0        8.0       0.0         0.0        1.0
# ...            ...        ...        ...       ...         ...        ...
# 31661          NaN        NaN        NaN       NaN         NaN        NaN
# 31662          NaN        NaN        NaN       NaN         NaN        NaN
# 31663          NaN        NaN        NaN       NaN         NaN        NaN
# 31664          NaN        NaN        NaN       NaN         NaN        NaN
# 31665          NaN        NaN        NaN       NaN         NaN        NaN
#
#       opp_killsat15 opp_assistsat15 opp_deathsat15
# 12468           0.0             0.0            0.0
# 12469           1.0             0.0            0.0
# 12470           1.0             1.0            0.0
# 12471           0.0             0.0            0.0
# 12472           0.0             2.0            0.0
# ...             ...             ...            ...
# 31661           NaN             NaN            NaN
# 31662           NaN             NaN            NaN
# 31663           NaN             NaN            NaN
# 31664           NaN             NaN            NaN
# 31665           NaN             NaN            NaN
#
# [50980 rows x 123 columns]

# %% [markdown]
# There are a number of columns that contain little to no data, so we are just going to remove them from the df. We would keep them if we were looking at team specific data.

# %%
playerdf = playerdf.drop(["firstdragon", 'dragons','opp_dragons','elementaldrakes','opp_elementaldrakes','infernals','mountains','clouds','oceans','dragons (type unknown)','elders','opp_elders','firstherald','heralds','opp_heralds','firstbaron','barons','opp_barons','firsttower','towers','opp_towers','firstmidtower','firsttothreetowers','turretplates','opp_turretplates','inhibitors','opp_inhibitors'], axis = 1)

# %% [markdown]
# Now that the data is cleaned up, lets separate it by region, and only take the region we want to test on. In this case,

# %%
leagueset = list(playerdf["league"])
leagueset = set(leagueset)
mainregions = pd.DataFrame()
league = ['LCS']
for item in league:
    throwaway = playerdf[playerdf["league"] == item]
    mainregions = mainregions.append(throwaway)

# %%
mainregions
# Out:
#                       gameid datacompleteness  url league  year   split  \
# 10524  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10525  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10526  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10527  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10528  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# ...                      ...              ...  ...    ...   ...     ...
# 2585   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2586   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2587   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2588   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2589   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
#
#        playoffs                 date  game  patch  ...  opp_csat15  \
# 10524         1  2022-01-29 22:00:54     2  12.02  ...       126.0
# 10525         1  2022-01-29 22:00:54     2  12.02  ...        97.0
# 10526         1  2022-01-29 22:00:54     2  12.02  ...       161.0
# 10527         1  2022-01-29 22:00:54     2  12.02  ...       131.0
# 10528         1  2022-01-29 22:00:54     2  12.02  ...        21.0
# ...         ...                  ...   ...    ...  ...         ...
# 2585          1  2022-01-14 21:26:31     1  12.01  ...       135.0
# 2586          1  2022-01-14 21:26:31     1  12.01  ...        81.0
# 2587          1  2022-01-14 21:26:31     1  12.01  ...       141.0
# 2588          1  2022-01-14 21:26:31     1  12.01  ...       138.0
# 2589          1  2022-01-14 21:26:31     1  12.01  ...        28.0
#
#       golddiffat15 xpdiffat15 csdiffat15 killsat15 assistsat15 deathsat15  \
# 10524      -1020.0     -339.0       -5.0       0.0         1.0        0.0
# 10525        555.0      294.0        6.0       3.0         0.0        1.0
# 10526      -1071.0    -1142.0      -39.0       0.0         1.0        1.0
# 10527      -1921.0    -1342.0      -11.0       0.0         2.0        2.0
# 10528       -611.0      -87.0        1.0       0.0         1.0        0.0
# ...            ...        ...        ...       ...         ...        ...
# 2585         -30.0     -206.0      -32.0       1.0         1.0        1.0
# 2586        1183.0      667.0       15.0       1.0         1.0        0.0
# 2587         946.0      618.0       17.0       0.0         1.0        0.0
# 2588        1699.0      385.0       21.0       0.0         1.0        0.0
# 2589         723.0      503.0        1.0       2.0         0.0        0.0
#
#       opp_killsat15 opp_assistsat15 opp_deathsat15
# 10524           2.0             0.0            0.0
# 10525           0.0             0.0            1.0
# 10526           0.0             0.0            1.0
# 10527           1.0             1.0            0.0
# 10528           1.0             0.0            1.0
# ...             ...             ...            ...
# 2585            0.0             1.0            1.0
# 2586            0.0             1.0            1.0
# 2587            0.0             1.0            1.0
# 2588            1.0             0.0            1.0
# 2589            0.0             1.0            0.0
#
# [1600 rows x 96 columns]

# %% [markdown]
# Lets add the new metrics to this dataset

# %%
mainregions["KDA"] = (mainregions["kills"]+mainregions["assists"]) / mainregions["deaths"]
mainregions["KP"] = (mainregions["kills"]+mainregions["assists"])  / mainregions["teamkills"]
mainregions["D%"] = mainregions["deaths"] / mainregions['teamdeaths']
mainregions["FantasyScore"] = (mainregions['kills']*3)-mainregions["deaths"]+(mainregions['assists']*1.5)+(mainregions["total cs"]*.02)
mainregions
# Out:
#                       gameid datacompleteness  url league  year   split  \
# 10524  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10525  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10526  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10527  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# 10528  ESPORTSTMNT02_2552332         complete  NaN    LCS  2022  Spring
# ...                      ...              ...  ...    ...   ...     ...
# 2585   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2586   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2587   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2588   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
# 2589   ESPORTSTMNT01_2691713         complete  NaN    LCS  2022  Spring
#
#        playoffs                 date  game  patch  ...  killsat15 assistsat15  \
# 10524         1  2022-01-29 22:00:54     2  12.02  ...        0.0         1.0
# 10525         1  2022-01-29 22:00:54     2  12.02  ...        3.0         0.0
# 10526         1  2022-01-29 22:00:54     2  12.02  ...        0.0         1.0
# 10527         1  2022-01-29 22:00:54     2  12.02  ...        0.0         2.0
# 10528         1  2022-01-29 22:00:54     2  12.02  ...        0.0         1.0
# ...         ...                  ...   ...    ...  ...        ...         ...
# 2585          1  2022-01-14 21:26:31     1  12.01  ...        1.0         1.0
# 2586          1  2022-01-14 21:26:31     1  12.01  ...        1.0         1.0
# 2587          1  2022-01-14 21:26:31     1  12.01  ...        0.0         1.0
# 2588          1  2022-01-14 21:26:31     1  12.01  ...        0.0         1.0
# 2589          1  2022-01-14 21:26:31     1  12.01  ...        2.0         0.0
#
#       deathsat15 opp_killsat15 opp_assistsat15 opp_deathsat15       KDA  \
# 10524        0.0           2.0             0.0            0.0  0.500000
# 10525        1.0           0.0             0.0            1.0  1.333333
# 10526        1.0           0.0             0.0            1.0  1.500000
# 10527        2.0           1.0             1.0            0.0  1.000000
# 10528        0.0           1.0             0.0            1.0  1.000000
# ...          ...           ...             ...            ...       ...
# 2585         1.0           0.0             1.0            1.0  8.000000
# 2586         0.0           0.0             1.0            1.0       inf
# 2587         0.0           0.0             1.0            1.0       inf
# 2588         0.0           1.0             0.0            1.0       inf
# 2589         0.0           0.0             1.0            0.0       inf
#
#              KP        D% FantasyScore
# 10524  0.200000  0.142857         4.18
# 10525  0.800000  0.214286        10.72
# 10526  0.600000  0.142857         7.18
# 10527  0.800000  0.285714        10.30
# 10528  0.600000  0.214286         2.24
# ...         ...       ...          ...
# 2585   0.533333  1.000000        18.08
# 2586   0.533333  0.000000        21.16
# 2587   0.533333  0.000000        20.76
# 2588   0.600000  0.000000        26.78
# 2589   0.733333  0.000000        20.32
#
# [1600 rows x 100 columns]

# %% [markdown]
# Time to reduce the datset even more. There are alot of variables not usefull for the analysis, so removing the variables is best for efficiency

# %%
variables = ['league','year','split','date','side',"playername",'position','teamname',"kills","deaths",'assists','doublekills','firstbloodkill'
             ,'firstbloodassist','firstbloodvictim','dpm','wpm','goldspent','total cs','minionkills','monsterkills',
             'monsterkillsenemyjungle','goldat15','xpat15','csat15','golddiffat15','xpdiffat15',
             'csdiffat15','killsat15','deathsat15','assistsat15','result','FantasyScore','KDA','KP','D%',"earnedgoldshare",
            'damageshare','cspm','damagetakenperminute','earnedgold','earned gpm']
#the commented section is if you are finding a null error in the factor reduction. In my case, the LCS 
#data doesn't have those issues, so I keep it commented out
reduced_df = mainregions[variables]#[mainregions["datacompleteness"]== 'complete'].dropna(how="any")

# %% [markdown]
# Now we can reduce the variables that we know have collinearity issues

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#The first variable will be the @15 minute variables
features15 = ['goldat15','xpat15','csat15']
x = reduced_df.loc[:,features15].values
y = reduced_df.loc[:,['playername']].values
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=1)
principalComponents = pca.fit_transform(x)
reduced_df['PCA15'] = principalComponents
print(pca.explained_variance_ratio_)

print(pca.components_)
# Out:
# [0.87632356]
# [[-0.570325   -0.56602845 -0.59526565]]
# <ipython-input-12-46c539c40df6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['PCA15'] = principalComponents

# %%
featureshare = ["earnedgoldshare",'damageshare']
x = reduced_df.loc[:,featureshare].values
y = reduced_df.loc[:,['playername']].values
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=1)
principalComponents = pca.fit_transform(x)
reduced_df['PCAShare'] = principalComponents
print(pca.explained_variance_ratio_)

print(pca.components_)
# Out:
# [0.90961848]
# [[0.70710678 0.70710678]]
# <ipython-input-13-d4d0799dd303>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['PCAShare'] = principalComponents

# %%
featureshare= ['earned gpm','cspm']
x = reduced_df.loc[:,featureshare].values
y = reduced_df.loc[:,["playername"]].values
x = StandardScaler().fit_transform(x)
#n_components should equal the total amount of components at the end
pca = PCA(n_components=1)
principalComponents = pca.fit_transform(x)
reduced_df["PCApm"] = principalComponents
print(pca.explained_variance_ratio_)

print(pca.components_)
# Out:
# [0.93571833]
# [[0.70710678 0.70710678]]
# <ipython-input-14-d9fd00d2a664>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df["PCApm"] = principalComponents

# %%
reduced_df['Counts'] = reduced_df.groupby(['playername'])['playername'].transform("count")
reduced_df
reduced_df.to_csv("2022_Reduced.csv", index = False)
# Out:
# <ipython-input-15-bd97fb2c2606>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Counts'] = reduced_df.groupby(['playername'])['playername'].transform("count")

# %% [markdown]
# Now that we have the reduced variables, we can test the data in the model created in a previous file.
# This code and old file will be brought in.

# %%
import statsmodels.api as sm

# %%
playerdf = pd.read_csv("PCATest1.csv")
playerdf = playerdf.rename(columns ={"total cs" : "total_cs"})#the statsmodel doesn't allow for spaces in variable names

# %%
variables = ['kills','deaths','assists','PCA15','PCAShare','PCApm']
x = playerdf[variables].to_numpy() 
y = playerdf["result"]

# %%
model = sm.Logit(y, sm.add_constant(x)).fit()
Y_pred = model.predict(sm.add_constant(x))
print_model = model.summary()
print(print_model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.245784
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 result   No. Observations:                92600
# Model:                          Logit   Df Residuals:                    92593
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 27 Apr 2022   Pseudo R-squ.:                  0.6454
# Time:                        12:34:12   Log-Likelihood:                -22760.
# converged:                       True   LL-Null:                       -64185.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.7205      0.031    -55.765      0.000      -1.781      -1.660
# x1             0.4857      0.007     65.458      0.000       0.471       0.500
# x2            -0.8946      0.009    -99.537      0.000      -0.912      -0.877
# x3             0.4696      0.004    108.081      0.000       0.461       0.478
# x4            -0.5684      0.017    -33.800      0.000      -0.601      -0.535
# x5            -2.3178      0.026    -88.354      0.000      -2.369      -2.266
# x6             2.8647      0.033     87.123      0.000       2.800       2.929
# ==============================================================================

# %% [markdown]
# Now that we have the original model, lets fit our 2022 data to this model

# %%
#reduced_df = pd.read_csv("2022_Reduced.csv")
newvariables = ['kills','deaths','assists','PCA15','PCAShare','PCApm'] # Sets X variables
x = reduced_df[newvariables].to_numpy() #makes the x variables an array, needed for the model
y = reduced_df["result"] # y variable

# %%
red_model = sm.Logit(y, sm.add_constant(x)).fit() #Creates model
Y_pred = red_model.predict(sm.add_constant(x)) #produces predictions
print_model = red_model.summary() #creates the summary table
reduced_df['predscore'] = Y_pred # adds predictions to df
print(print_model)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.240386
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 result   No. Observations:                 1600
# Model:                          Logit   Df Residuals:                     1593
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 27 Apr 2022   Pseudo R-squ.:                  0.6532
# Time:                        12:34:12   Log-Likelihood:                -384.62
# converged:                       True   LL-Null:                       -1109.0
# Covariance Type:            nonrobust   LLR p-value:                6.446e-310
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.8350      0.250     -7.343      0.000      -2.325      -1.345
# x1             0.4864      0.062      7.787      0.000       0.364       0.609
# x2            -0.9840      0.075    -13.177      0.000      -1.130      -0.838
# x3             0.5625      0.037     15.111      0.000       0.490       0.635
# x4             0.5369      0.140      3.838      0.000       0.263       0.811
# x5            -2.0661      0.208     -9.952      0.000      -2.473      -1.659
# x6             2.6703      0.282      9.458      0.000       2.117       3.224
# ==============================================================================
# <ipython-input-21-f35ff1d14e11>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['predscore'] = Y_pred # adds predictions to df

# %% [markdown]
# Now that We have this new 2022 model, we can see the rank the teams based on the predicted scores

# %%
predict_df = reduced_df.groupby('teamname', as_index = False)['predscore'].mean()
predict_df.sort_values(by=['predscore'])
# Out:
#                teamname  predscore
# 7             Immortals   0.315123
# 2  Counter Logic Gaming   0.348390
# 8                   TSM   0.356633
# 6      Golden Guardians   0.378550
# 5              FlyQuest   0.396684
# 3              Dignitas   0.447762
# 1                Cloud9   0.560809
# 0           100 Thieves   0.590080
# 4         Evil Geniuses   0.635076
# 9           Team Liquid   0.658021

# %% [markdown]
# We can do the same with players, and the player with the highest average score would be MVP

# %%
#We need to drop players that played less than the half of the games in the regular season.
#This is how Riot Games determines mvps, so this model will as well. 
mvp = reduced_df.groupby('Counts').filter(lambda x: len(x)>9)

mvp_df = mvp.groupby('playername',as_index = False)['predscore'].mean()
mvp_df.sort_values(by=['predscore']).nlargest(10,"predscore")
#mvp_df.to_csv("2022_MVP.csv",index = False)
# Out:
#    playername  predscore
# 5    Bjergsen   0.748510
# 25   Inspired   0.743803
# 44   Santorin   0.732451
# 13      Danny   0.681534
# 20  Hans sama   0.677710
# 19      Fudge   0.667841
# 10     Closer   0.659913
# 3   Berserker   0.641761
# 47    Ssumday   0.639376
# 16       Eyla   0.639033

# %% [markdown]
# According to this model, Bjergsen should have been the Spring Split MVP, if you include playoff games. Typically MVP is based only on regular season, but I like the regular + post season MVP discussion better.

# %% [markdown]
# This section is getting important info from the model for the writting of the paper

# %%
params = red_model.params
exp = np.exp(params)
exp
# Out:
# const     0.159610
# x1        1.626441
# x2        0.373817
# x3        1.755004
# x4        1.710729
# x5        0.126673
# x6       14.444928
# dtype: float64

# %%
conf = red_model.conf_int()
conf = np.exp(conf)
conf
#multipliers, just like above
# Out:
#               0          1
# const  0.097802   0.260479
# x1     1.439041   1.838244
# x2     0.322919   0.432736
# x3     1.631529   1.887824
# x4     1.300516   2.250332
# x5     0.084328   0.190281
# x6     8.305868  25.121512

# %% [markdown]
# This is all test, probably deleting

# %%
reduced_df["earnedgoldshare"] = reduced_df['earnedgoldshare']*100
# Out:
# <ipython-input-32-1d48e2caf3f8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df["earnedgoldshare"] = reduced_df['earnedgoldshare']*100

# %%
vas = ['kills','deaths','assists','goldat15','xpat15',"earnedgoldshare",'earned gpm']
x = reduced_df[vas].to_numpy() #makes the x variables an array, needed for the model
y = reduced_df["result"] # y variable

test_model = sm.Logit(y, sm.add_constant(x)).fit() #Creates model
Y_pred = test_model.predict(sm.add_constant(x)) #produces predictions
print_model = test_model.summary() #creates the summary table
#reduced_df['predscore'] = Y_pred # adds predictions to df
print(print_model)

# %%
from sklearn.metrics import confusion_matrix
y_pred = list()
for item in Y_pred:
    if item >.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

y_true = reduced_df['result']

cm = confusion_matrix(y_true,y_pred)
numerator = cm[0,0]+cm[1,1]
denom = numerator + cm[0,1]+cm[1,0]
acc = numerator/ denom
acc
# Out:
# 0.944375

# %%
params = test_model.params
exp = np.exp(params)
exp
# Out:
# const    5.748310
# x1       1.182444
# x2       0.362407
# x3       1.350742
# x4       0.998995
# x5       1.000374
# x6       1.009929
# x7       0.220726
# x8       0.240453
# x9       1.153531
# x10      0.773179
# dtype: float64

# %%
conf = test_model.conf_int()
conf = np.exp(conf)
conf
# Out:
#               0          1
# const  0.605066  54.610649
# x1     0.958195   1.459176
# x2     0.292698   0.448717
# x3     1.230370   1.482890
# x4     0.998350   0.999640
# x5     0.999991   1.000757
# x6     0.986229   1.034198
# x7     0.171176   0.284620
# x8     0.002410  23.995487
# x9     1.126971   1.180717
# x10    0.515095   1.160575

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
vas = ['kills','deaths','assists','goldat15','xpat15',"earnedgoldshare",'earned gpm']
x_train = playerdf[vas]
y_train = playerdf["result"]

x_test = reduced_df[vas]
y_test = reduced_df["result"]

log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# C:\Users\jacks\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
y_pred_proba = log_reg.predict_proba(x_test)[:,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

auc = metrics.roc_auc_score(y_test, y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(log_reg, x_train, y_train, cv=10)
print('Cross-Validation Accuracy Scores', scores)
# Out:
# C:\Users\jacks\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\jacks\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\jacks\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\jacks\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Accuracy Scores [0.89308855 0.8849892  0.88790497 0.88920086 0.88639309 0.88347732
#  0.88617711 0.88855292 0.88488121 0.87732181]

# %%
scores = pd.Series(scores)
scores.min(), scores.mean(), scores.max()
# Out:
# (0.8773218142548597, 0.8861987041036719, 0.8930885529157667)
